# %%
import pandas as pd

# %%
org_twitter = pd.read_csv('Data/organizations.csv',low_memory=False)

# %%
org_twitter['facebook_url'].dropna(inplace=True)

# %%
org_twitter['linkedin_url'].dropna(inplace=True)

# %%
org_twitter.dropna(subset = ['facebook_url','twitter_url','linkedin_url'],axis=0,inplace=True)

# %%
# Select only company in primary role

org_twitter = org_twitter[org_twitter['primary_role'] == 'company']

# %%
org_twitter
# Out:
#                                          uuid                         name  \
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                         Zoho
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                         Digg
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb                         Meta
# 9        4111dc8b-c0df-2d24-ed33-30cd137b3098                         Geni
# 12       5da6106f-0d27-0d37-e9d7-dcfeccc1f709                      Twitter
# ...                                       ...                          ...
# 2597986  22cf64e4-d1c6-4b97-83fb-700436106f26         Seller Finance Dream
# 2597987  fd5caeba-bbf0-441e-ac33-ca349005442d                Shane Parkins
# 2597994  ea6c4981-53a8-47d2-82e7-298daf5b78a9             Boulder Symphony
# 2597996  d55e196b-c803-4a37-b876-a846f52defcb  Beachland Ballroom & Tavern
# 2597997  618002b8-cbde-4069-82bb-82c45ceed3c7               Decades Rewind
#
#                  type                  permalink  \
# ...

# %%
org_twitter_200 = org_twitter[:500]

# %%
org_twitter_200
# Out:
#                                       uuid         name          type  \
# 1     bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7         Zoho  organization
# 2     5f2b40b8-d1b3-d323-d81a-b7a8e89553d0         Digg  organization
# 4     df662812-7f97-0b43-9d3e-12f64f504fbb         Meta  organization
# 9     4111dc8b-c0df-2d24-ed33-30cd137b3098         Geni  organization
# 12    5da6106f-0d27-0d37-e9d7-dcfeccc1f709      Twitter  organization
# ...                                    ...          ...           ...
# 1776  ea7ed226-88e1-43c3-b75c-e05e9e5c29b0    Splashtop  organization
# 1784  be9fe350-1f7e-c468-00e5-e977d65c0541    Livemocha  organization
# 1786  dc416ea6-d6cf-f549-e53c-03a618d90445   Mint Bills  organization
# 1792  a2dd7184-7598-9c6d-28dd-829cbb78a9a9  Engine Yard  organization
# 1793  e497bb8b-bc47-8eaf-b9a2-ae9b45b14fa4       Joyent  organization
#
#        permalink                                             cb_url      rank  \
# ...

# %%
# Save the organisation with SM details
org_twitter.to_csv('data/org_with_sm.csv',index=True)

# %%
# Save the the organisation with SM details Subset Dataset
org_twitter_200.to_csv('data/org_with_sm_500.csv',index=False)
