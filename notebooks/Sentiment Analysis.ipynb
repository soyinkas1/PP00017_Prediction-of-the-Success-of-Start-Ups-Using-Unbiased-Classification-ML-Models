# %% [markdown]
# **Problem Statement**
# This notebook would be used to carry out sentiment analysis on the tweets about organisations. The data would also capture the number of followers and following in numeric datatype. The output from the analysis would be presented as a dataframe containing the list of companies as rows and the average polarity , average subjectivity, number of followers and number of followings as the columns.
#
# **Data**
# The data for each company is available as csv and it will be preprocessed accordlingly for NLP processing.
#
# **Tools**
# The python libraries to be used are Pandas & TextBlob.

# %%
#!pip install TextBlob

# %%
# Data Manipulation and cleaning Libraries
import numpy as np
import re
import pandas as pd

# File system libraries
from os import listdir
from os.path import isfile, join

# NLP processing libraries
from textblob import TextBlob

# %%
# Add the file names to a list
files = [f for f in listdir("C:\\Users\\VG\OneDrive - Cardiff Metropolitan University\\Document Management\\Dissertation\\Crunchbase Data\\tweets") if isfile(join("C:\\Users\\VG\\OneDrive - Cardiff Metropolitan University\\Document Management\\Dissertation\\Crunchbase Data\\tweets", f))]

# %%
# Peep at the list 
files[:4]
# Out:
# ['.csv', '1NorthEnlight.csv', '23andMe.csv', '4INFO.csv']

# %%
# Read the all the dataset into a dictionary of DataFrames
data = {}

for i in range(0,len(files)+1):
    try:
        df = pd.read_csv("tweets/"+files[i],usecols=['account','text','follower_data','following_data'])
        data[f'{files[i].split(".")[0]}'] = df
    except:
        pass

# %%
# Helper function clean tweet text
def clean_tweet(tweet):
    """
    Parameters:
    ----------
    Tweet: String type of the tweet content
    
    Returns:
    ---------
    cleaned version of the string tweet
    
    """
    tweet =tweet.lower()# Lowercasing all the letters
    tweet= re.sub("@[A-Za-z0-9_]+","", tweet) # Remove all the mentions
    tweet = re.sub("#[A-Za-z0-9_]+","", tweet) # Remove all the hashtags
    tweet = re.sub(r"http\S+", "", tweet) # Remove the URL
    tweet = re.sub(r"www.\S+", "", tweet) # Remove the URL
    tweet= re.sub('[()!?]', ' ', tweet) # Remove punctuations
    tweet = re.sub('\[.*?\]',' ', tweet) # Remove punctuations
    tweet= re.sub("[^a-z0-9]"," ", tweet) # Remove all non-alphanumeric characters

    return tweet

# Helper function clean tweet in all DataFrames
def clean_dict(data):
    """
    Parameters:
    ----------
    data: Dictionary of the DataFrames with tweets to clean
    
    Returns:
    ---------
    Dictionary of DataFrame with clean tweets
    
    """

    for key, val in data.items():
        val.dropna(subset=['text'],inplace=True)# Drop NAs
        data[key]=val # Update dictionary

        new_string = [] # create list to store cleaned tweets
        for tweet in val['text']:
            tweet = clean_tweet(tweet) # Clean tweets
            new_string.append(tweet)
        
        val['text']=new_string # update the dataframe with clean tweet
        data[key]=val
    return  data

# %%
# Clean the tweet datasets and save in a dictionary
data_c = clean_dict(data)

# %%
# Calculate and add the polarity and subjectivity columns
for key, val in data_c.items():
    for item in val['follower_data']:
        if str(item).find('K') != -1:
            item = re.sub("[^0-9.]","", item) # format the K to '000'
            item = float(item)*1000
#             print(item)
            val['follower_data'] = item
            data_c[key]=val
        elif str(item).find('M') != -1:
            item = re.sub("[^0-9.]","", item) # format the M to '000000'
            item = float(item)*1000000
#             print(item)
            val['follower_data'] = item
            data_c[key]=val
    try:        
        val['polarity']=val['text'].apply(lambda x:TextBlob(x).sentiment.polarity)# Calculates and add polarity columns
        val['subjectivity']=val['text'].apply(lambda x:TextBlob(x).sentiment.subjectivity)      
        data_c[key]=val # Update dictionary
    except:
        pass

# %%
# Check the output
data_c
# Out:
# {'':                                  account  \
#  0   https://twitter.com/jellyfishglobal/
#  3   https://twitter.com/jellyfishglobal/
#  5   https://twitter.com/jellyfishglobal/
#  6   https://twitter.com/jellyfishglobal/
#  8   https://twitter.com/jellyfishglobal/
#  9   https://twitter.com/jellyfishglobal/
#  11  https://twitter.com/jellyfishglobal/
#  12  https://twitter.com/jellyfishglobal/
#  15  https://twitter.com/jellyfishglobal/
#  16  https://twitter.com/jellyfishglobal/
#  17  https://twitter.com/jellyfishglobal/
#  18  https://twitter.com/jellyfishglobal/
#  19  https://twitter.com/jellyfishglobal/
#  23  https://twitter.com/jellyfishglobal/
#  25  https://twitter.com/jellyfishglobal/
#  26  https://twitter.com/jellyfishglobal/
#
#                                                   text follower_data  \
#  0    if use of the platform is restricted as a res...         6,811
#  3   is our industry s obsession with roas stunting...         6,811
#  5   how can marketers can learn from gaming commun...         6,811
#  6   who s on tv  oh it s just  and  on  with  help...         6,811
#  8   on tuesday  25th january at 10am gmt   11am ce...         6,811
#  9   tiktok isn t going away anytime soon  so  expl...         6,811
#  11                                          newsflash         6,811
#  12  we re so excited to announce that    our ceo  ...         6,811
#  15  we are officially launching jfa16  the 16th an...         6,811
#  16   join us next thursday at 11am to discuss how ...         6,811
#  17                                                            6,811
#  18  check out how our technology solutions can hel...         6,811
#  19  we re excited to launch jellyfish technology s...         6,811
#  23                                     well said by           6,811
#  25  haven t heard of us  well  check out this arti...         6,811
#  26  just another typical day in the office chattin...         6,811
#
#     following_data  polarity  subjectivity
#  0           2,012  0.344444      0.522222
#  3           2,012  0.000000      0.300000
#  5           2,012  0.000000      0.000000
#  6           2,012  0.000000      0.000000
#  8           2,012  0.000000      0.000000
#  9           2,012  0.000000      0.000000
#  11          2,012  0.000000      0.000000
#  12          2,012  0.375000      0.750000
#  15          2,012  0.000000      0.000000
#  16          2,012  0.000000      0.000000
#  17          2,012  0.000000      0.000000
#  18          2,012 -0.100000      0.050000
#  19          2,012  0.125000      0.583333
#  23          2,012  0.000000      0.000000
#  25          2,012  0.000000      0.250000
#  26          2,012 -0.166667      0.500000  ,
#  '1NorthEnlight':                             account  \
#  0  http://twitter.com/1NorthEnlight
#  1  http://twitter.com/1NorthEnlight
#
#                                                  text  follower_data  \
#  0       why is  so happy with    find out at the                  5
#  1  a short video of the always entertaining   par...              5
#
#     following_data  polarity  subjectivity
#  0               7  0.800000      1.000000
#  1               7  0.083333      0.411111  ,
#  '23andMe':                        account  \
#  0   http://twitter.com/23andMe
#  3   http://twitter.com/23andMe
#  5   http://twitter.com/23andMe
#  7   http://twitter.com/23andMe
#  9   http://twitter.com/23andMe
#  10  http://twitter.com/23andMe
#  13  http://twitter.com/23andMe
#  15  http://twitter.com/23andMe
#  16  http://twitter.com/23andMe
#  17  http://twitter.com/23andMe
#  18  http://twitter.com/23andMe
#  19  http://twitter.com/23andMe
#  20  http://twitter.com/23andMe
#  21  http://twitter.com/23andMe
#  24  http://twitter.com/23andMe
#  26  http://twitter.com/23andMe
#
#                                                   text  follower_data  \
#  0                                 second look tonight        92900.0
#  3   23andme sent me an email this morning about fi...        92900.0
#  5   went to go see katt williams 23 and me tour la...        92900.0
#  7   note also folks  that some people with rare hl...        92900.0
#  9        nazi race scientists would ve loved 23andme         92900.0
#  10  nah  i m not a dominican  though i ve never do...        92900.0
#  13                           i got my 23andme report         92900.0
#  15  examination of our own genetic ancestry via 23...        92900.0
#  16  i mean  she looks like she s white   someone n...        92900.0
#  17    bro you re not native american cause of 23andme        92900.0
#  18  she needs to do a 23 and me  i don t think she...        92900.0
#  19   spotlight on whm anne e wojcicki an american ...        92900.0
#  20  someone needs to check his 23andme results cau...        92900.0
#  21  why pay for 23 and me if amazon can figure out...        92900.0
#  24  he should get his 23andme  i would be willing ...        92900.0
#  26  this site says you can t use 23andme for this ...        92900.0
#
#     following_data  polarity  subjectivity
#  0           6,814  0.000000      0.000000
#  3           6,814 -0.181818      0.477273
#  5           6,814  0.400000      0.473333
#  7           6,814  0.155556      0.688889
#  9           6,814  0.700000      0.800000
#  10          6,814  0.000000      0.000000
#  13          6,814  0.000000      0.000000
#  15          6,814  0.250000      0.650000
#  16          6,814 -0.156250      0.343750
#  17          6,814  0.000000      0.000000
#  18          6,814  0.000000      0.000000
#  19          6,814  0.012500      0.216667
#  20          6,814  0.000000      0.000000
#  21          6,814  0.800000      0.700000
#  24          6,814  0.027778      0.272222
#  26          6,814 -0.500000      1.000000  ,
#  '4INFO':                     account  \
#  0  http://twitter.com/4INFO
#
#                                                  text follower_data  \
#  0  health benefits  treat kidney stones treatment...         2,109
#
#    following_data  polarity  subjectivity
#  0          2,061     0.375          0.75  ,
#  'A123Systems':                           account  \
#  0  http://twitter.com/A123Systems
#
#                                                  text follower_data  \
#  0  the global battery market size is expected to ...         1,844
#
#     following_data  polarity  subjectivity
#  0             185  0.012121      0.284848  ,
#  'ab_insights':                            account  \
#  0   http://twitter.com/ab_insights
#  3   http://twitter.com/ab_insights
#  5   http://twitter.com/ab_insights
#  6   http://twitter.com/ab_insights
#  7   http://twitter.com/ab_insights
#  9   http://twitter.com/ab_insights
#  11  http://twitter.com/ab_insights
#  12  http://twitter.com/ab_insights
#  14  http://twitter.com/ab_insights
#  15  http://twitter.com/ab_insights
#  16  http://twitter.com/ab_insights
#  17  http://twitter.com/ab_insights
#  18  http://twitter.com/ab_insights
#  19  http://twitter.com/ab_insights
#  21  http://twitter.com/ab_insights
#  22  http://twitter.com/ab_insights
#  24  http://twitter.com/ab_insights
#  25  http://twitter.com/ab_insights
#
#                                                   text  follower_data  \
#  0   ab s co head of fixed income gershon distenfel...        22800.0
#  3   chuck penner compares estimates for the 2023 2...        22800.0
#  5   can you share some insights about logic behind...        22800.0
#  6   can you share some insights about the logic be...        22800.0
#  7   r evolution can now see operational performanc...        22800.0
#  9   gain insights into the differences between ab ...        22800.0
#  11  pakistan abhi recently hee apne home ground ma...        22800.0
#  12  discover our interview with michael pelsoci  r...        22800.0
#  14  the future of marketing  ai powered forecastin...        22800.0
#  15                                               knnl        22800.0
#  16   was invited to participate as one of the lead...        22800.0
#  17  mucopolysaccharidosis type i pipeline drugs an...        22800.0
#  18  cushing s syndrome pipeline drugs and companie...        22800.0
#  19  heute ab 17 30 uhr beim  in salzburg  bei der ...        22800.0
#  21   this creates a positive  collaborative enviro...        22800.0
#  22  i am excited to announce our new expert soluti...        22800.0
#  24  i just saw a tweet from  and i have to say he ...        22800.0
#  25   virtual seminar  a knowledge intensive broadc...        22800.0
#
#      following_data  polarity  subjectivity
#  0              819  0.050000      0.350000
#  3              819  0.500000      0.900000
#  5              819 -0.400000      0.700000
#  6              819 -0.400000      0.700000
#  7              819 -0.077778      0.644444
#  9              819  0.000000      0.000000
#  11             819  0.125000      0.263889
#  12             819  0.166667      0.377778
#  14             819  0.019481      0.372078
#  15             819  0.000000      0.000000
#  16             819  0.068182      0.227273
#  17             819  0.100000      0.100000
#  18             819  0.100000      0.100000
#  19             819  0.500000      0.500000
#  21             819  0.575758      0.715152
#  22             819  0.255682      0.602273
#  24             819  0.460000      0.530000
#  25             819  0.450000      0.500000  ,
#  'AdaptivePath':                             account  \
#  0   http://twitter.com/AdaptivePath
#  3   http://twitter.com/AdaptivePath
#  5   http://twitter.com/AdaptivePath
#  6   http://twitter.com/AdaptivePath
#  8   http://twitter.com/AdaptivePath
#  9   http://twitter.com/AdaptivePath
#  11  http://twitter.com/AdaptivePath
#  12  http://twitter.com/AdaptivePath
#  13  http://twitter.com/AdaptivePath
#  15  http://twitter.com/AdaptivePath
#  16  http://twitter.com/AdaptivePath
#
#                                                   text  follower_data  \
#  0   lots of great wisdom from  peter merholz co fo...        43400.0
#  3   lots of  in   s       with  people        incl...        43400.0
#  5    design is interesting because it s weird   sa...        43400.0
#  6   worth noting that four years ago  capitalone a...        43400.0
#  8   while  gets hyped on acquisition of design fir...        43400.0
#  9   i have been listening to the finding our way p...        43400.0
#  11  i guess i stole more office supplies than the ...        43400.0
#  12  running ap s events was the best  and even mor...        43400.0
#  13  besides generic google  here s detailed notes ...        43400.0
#  15  simultaneously   hired me to copy edit    that...        43400.0
#  16                           you re not the only one         43400.0
#
#      following_data  polarity  subjectivity
#  0              572  0.700000      0.825000
#  3              572  0.000000      0.000000
#  5              572  0.000000      0.700000
#  6              572  0.300000      0.100000
#  8              572  0.000000      0.100000
#  9              572  0.000000      0.000000
#  11             572  0.175000      0.358333
#  12             572  0.833333      0.366667
#  13             572  0.258333      0.541667
#  15             572  0.500000      0.500000
#  16             572  0.000000      1.000000  ,
#  'adBrite':                        account  \
#  0   http://twitter.com/adBrite
#  1   http://twitter.com/adBrite
#  2   http://twitter.com/adBrite
#  4   http://twitter.com/adBrite
#  5   http://twitter.com/adBrite
#  6   http://twitter.com/adBrite
#  7   http://twitter.com/adBrite
#  8   http://twitter.com/adBrite
#  9   http://twitter.com/adBrite
#  10  http://twitter.com/adBrite
#  11  http://twitter.com/adBrite
#  12  http://twitter.com/adBrite
#  13  http://twitter.com/adBrite
#  14  http://twitter.com/adBrite
#  15  http://twitter.com/adBrite
#  16  http://twitter.com/adBrite
#  17  http://twitter.com/adBrite
#  18  http://twitter.com/adBrite
#
#                                                   text  follower_data  \
#  0                           did google kill adbrite              881
#  1   adbrite step by step  how to make money  tutor...            881
#  2   easy advertising  with adbrite   3 simple and ...            881
#  4   sitescout acquires ip developed by defunct ad ...            881
#  5    infolinks adbrite and google adsense pays me ...            881
#  6   founder institute w  adbrite founder philip ka...            881
#  7   the former ad network turned ad exchange adbri...            881
#  8   online earning tips with different alternative...            881
#  9   looking for a google adsense alternative  do n...            881
#  10  adbrite s future isn t  ceasing operations on ...            881
#  11  may 2007  this is when i removed adbrite s ban...            881
#  12  1   kaplan is a regular startup founder  first...            881
#  13  nobody ever talks about how sequoia investment...            881
#  14    sitescout acquires ip assets from adbrite  via             881
#  15  fuck the users  fuck the brand  fat burning ad...            881
#  16  toronto s sitescout acquires intellectual prop...            881
#  17  sitescout acquires ip developed by defunct ad ...            881
#  18  i find it humerus when a company starts emulat...            881
#
#      following_data  polarity  subjectivity
#  0              205  0.000000      0.000000
#  1              205  0.000000      0.000000
#  2              205  0.288889      0.674603
#  4              205 -0.018519      0.362963
#  5              205  0.000000      0.000000
#  6              205  0.400000      0.800000
#  7              205  0.300000      0.400000
#  8              205  0.000000      0.600000
#  9              205  0.600000      0.800000
#  10             205  0.000000      0.125000
#  11             205  0.175000      0.775000
#  12             205  0.125000      0.205128
#  13             205  0.100000      0.600000
#  14             205  0.000000      0.000000
#  15             205 -0.221212      0.551515
#  16             205  0.300000      0.400000
#  17             205  0.100000      0.300000
#  18             205  0.214286      0.428571  ,
#  'addthis':                        account  \
#  0   http://twitter.com/addthis
#  1   http://twitter.com/addthis
#  4   http://twitter.com/addthis
#  6   http://twitter.com/addthis
#  7   http://twitter.com/addthis
#  9   http://twitter.com/addthis
#  10  http://twitter.com/addthis
#  12  http://twitter.com/addthis
#  13  http://twitter.com/addthis
#  14  http://twitter.com/addthis
#  15  http://twitter.com/addthis
#  16  http://twitter.com/addthis
#  17  http://twitter.com/addthis
#  18  http://twitter.com/addthis
#  19  http://twitter.com/addthis
#  20  http://twitter.com/addthis
#  21  http://twitter.com/addthis
#  22  http://twitter.com/addthis
#  24  http://twitter.com/addthis
#  25  http://twitter.com/addthis
#
#                                                   text  follower_data  \
#  0                  congratulations     addthis   home      2000000.0
#  1                                      addthis   home      2000000.0
#  4   senator wiener s historic bill to provide refu...      2000000.0
#  6   2022 hero cpl generates  200 million   old har...      2000000.0
#  7   convicted police imposter oshain myers reporte...      2000000.0
#  9                                      addthis   home      2000000.0
#  10  very happy to share our latest paper headed by...      2000000.0
#  12  learn how to bring skilled professionals to th...      2000000.0
#  13  learn how to bring skilled professionals to th...      2000000.0
#  14                                     addthis   home      2000000.0
#  15  budget overview meeting on march 16  2023 at 7...      2000000.0
#  16                                     addthis   home      2000000.0
#  17  final meeting public meeting hazard mitigation...      2000000.0
#  18   president will no longer chair faculty meetin...      2000000.0
#  19                             do anything for voters      2000000.0
#  20  dejo por aqu  nuestra reflexi n publicada en c...      2000000.0
#  21  the hood school communication board   north re...      2000000.0
#  22  people rsquo s defence force attacks myanmar a...      2000000.0
#  24  addthis   home our new manuscript published in...      2000000.0
#  25  where have the striped bass gone    cape gazet...      2000000.0
#
#      following_data  polarity  subjectivity
#  0              784  0.000000      0.000000
#  1              784  0.000000      0.000000
#  4              784  0.000000      0.000000
#  6              784  0.100000      0.200000
#  7              784 -0.050000      0.125000
#  9              784  0.000000      0.000000
#  10             784  0.633333      0.900000
#  12             784  0.500000      0.500000
#  13             784  0.500000      0.500000
#  14             784  0.000000      0.000000
#  15             784  0.000000      0.000000
#  16             784  0.000000      0.000000
#  17             784  0.000000      0.533333
#  18             784  0.000000      0.000000
#  19             784  0.000000      0.000000
#  20             784  0.000000      0.000000
#  21             784  0.000000      0.066667
#  22             784 -0.800000      1.000000
#  24             784  0.021645      0.222944
#  25             784 -0.150000      0.500000  ,
#  'adobedoccloud':                             account  \
#  0  http://twitter.com/adobedoccloud
#  1  http://twitter.com/adobedoccloud
#  3  http://twitter.com/adobedoccloud
#  4  http://twitter.com/adobedoccloud
#  5  http://twitter.com/adobedoccloud
#  6  http://twitter.com/adobedoccloud
#  7  http://twitter.com/adobedoccloud
#
#                                                  text  follower_data  \
#  0  imagine keeping documents in physical folders ...        45100.0
#  1                     how are you tuning into  2023         45100.0
#  3                                   you ve got this         45100.0
#  4                     takes a great deal of courage         45100.0
#  5                                        never fails        45100.0
#  6                             that s all you can do         45100.0
#  7  there s definitely a reason he has a crown on ...        45100.0
#
#    following_data  polarity  subjectivity
#  0          3,482      0.00      0.142857
#  1          3,482      0.00      0.000000
#  3          3,482      0.00      0.000000
#  4          3,482      0.80      0.750000
#  5          3,482      0.25      0.300000
#  6          3,482      0.00      0.000000
#  7          3,482      0.00      0.500000  ,
#  'AdReady':                        account  \
#  0   http://twitter.com/AdReady
#  1   http://twitter.com/AdReady
#  2   http://twitter.com/AdReady
#  3   http://twitter.com/AdReady
#  4   http://twitter.com/AdReady
#  5   http://twitter.com/AdReady
#  6   http://twitter.com/AdReady
#  7   http://twitter.com/AdReady
#  8   http://twitter.com/AdReady
#  9   http://twitter.com/AdReady
#  10  http://twitter.com/AdReady
#  11  http://twitter.com/AdReady
#  12  http://twitter.com/AdReady
#  13  http://twitter.com/AdReady
#  14  http://twitter.com/AdReady
#  15  http://twitter.com/AdReady
#  16  http://twitter.com/AdReady
#  17  http://twitter.com/AdReady
#  18  http://twitter.com/AdReady
#  19  http://twitter.com/AdReady
#  20  http://twitter.com/AdReady
#  21  http://twitter.com/AdReady
#  22  http://twitter.com/AdReady
#  23  http://twitter.com/AdReady
#  24  http://twitter.com/AdReady
#  25  http://twitter.com/AdReady
#  26  http://twitter.com/AdReady
#  27  http://twitter.com/AdReady
#  28  http://twitter.com/AdReady
#  29  http://twitter.com/AdReady
#  30  http://twitter.com/AdReady
#  31  http://twitter.com/AdReady
#  32  http://twitter.com/AdReady
#  33  http://twitter.com/AdReady
#  34  http://twitter.com/AdReady
#  35  http://twitter.com/AdReady
#  36  http://twitter.com/AdReady
#  37  http://twitter.com/AdReady
#
#                                                   text follower_data  \
#  0                are cooling on snapchat live stories         3,128
#  1    is adding 15 ad tech companies to beef up its...         3,128
#  2   are you ready for  masters of  this week  we a...         3,128
#  3   proud to announce that our parent company  has...         3,128
#  4   60  of mobile banner ad clicks are mistakes  s...         3,128
#  5   solera s autopoint announces launch of groundb...         3,128
#  6   the marriage of creative and programmatic  it ...         3,128
#  7   ad viewability is falling across europe   who ...         3,128
#  8    search vs  display  everything you need to know          3,128
#  9   what a  5 million super bowl ad can buy you in...         3,128
#  10   fat thumbs  generate up to 60  of mobile ad c...         3,128
#  11            the impact of  on creative advertising          3,128
#  12  unilever  digital  verification must improve t...         3,128
#  13  5 steps to a winning display advertising strat...         3,128
#  14      s  says 2016 is not the year of cross devi...         3,128
#  15  a conversation with revjet s ceo  optimizing a...         3,128
#  16  brand networks reveals pace and scale of inves...         3,128
#  17  the economist  finding new readers with creati...         3,128
#  18   by 2017  88  of mobile display ads will be bo...         3,128
#  19  postmedia increases direct sales efficiency wi...         3,128
#  20  groupm strikes 100   deal on display and video...         3,128
#  21               give display the credit it deserves          3,128
#  22  case study  how an online retailer turned sale...         3,128
#  23               sprint to offer display app for ads          3,128
#  24  hornby calls for concerted industry action on ...         3,128
#  25  putting a premium on ad viewability  how to pr...         3,128
#  26  in 2016  search ads predicted to grow but disp...         3,128
#  27  these advertising mistakes will lower your con...         3,128
#  28             the problem with   and how to fix it           3,128
#  29  european ssp improve digital launches guarante...         3,128
#  30  it s your last chance to meet with our team at...         3,128
#  31  2016 sees display ad spend overtake search in ...         3,128
#  32  when tying engagement to   the key lies in  un...         3,128
#  33             israeli adtech looks to scale up  via          3,128
#  34                                so long liverail            3,128
#  35  learn more about adready s extensive mobile in...         3,128
#  36           four display advertising trends in apac          3,128
#  37  the 10 display advertising mistakes to avoid i...         3,128
#
#     following_data  polarity  subjectivity
#  0           1,316  0.136364      0.500000
#  1           1,316 -0.400000      0.400000
#  2           1,316  0.400000      0.762963
#  3           1,316  0.516667      0.566667
#  4           1,316  0.000000      0.000000
#  5           1,316  0.000000      0.000000
#  6           1,316  0.500000      1.000000
#  7           1,316  0.500000      0.500000
#  8           1,316  0.000000      0.000000
#  9           1,316  0.166667      0.333333
#  10          1,316  0.000000      0.000000
#  11          1,316  0.500000      1.000000
#  12          1,316  0.400000      0.200000
#  13          1,316  0.500000      0.750000
#  14          1,316  0.000000      0.000000
#  15          1,316  0.250000      0.500000
#  16          1,316  0.000000      0.000000
#  17          1,316  0.318182      0.727273
#  18          1,316  0.000000      0.000000
#  19          1,316  0.100000      0.400000
#  20          1,316  0.000000      0.000000
#  21          1,316  0.000000      0.000000
#  22          1,316  0.000000      0.000000
#  23          1,316  0.000000      0.000000
#  24          1,316  0.100000      0.100000
#  25          1,316  0.000000      0.000000
#  26          1,316  0.000000      0.500000
#  27          1,316  0.000000      0.000000
#  28          1,316  0.000000      0.000000
#  29          1,316  0.000000      0.000000
#  30          1,316  0.250000      0.283333
#  31          1,316  0.000000      0.000000
#  32          1,316  0.000000      1.000000
#  33          1,316  0.000000      0.000000
#  34          1,316 -0.050000      0.400000
#  35          1,316  0.250000      0.416667
#  36          1,316  0.000000      0.000000
#  37          1,316  0.000000      0.125000  ,
#  'airGChat':                         account  \
#  0   http://twitter.com/airGChat
#  3   http://twitter.com/airGChat
#  4   http://twitter.com/airGChat
#  5   http://twitter.com/airGChat
#  6   http://twitter.com/airGChat
#  7   http://twitter.com/airGChat
#  8   http://twitter.com/airGChat
#  10  http://twitter.com/airGChat
#  11  http://twitter.com/airGChat
#  12  http://twitter.com/airGChat
#  13  http://twitter.com/airGChat
#  14  http://twitter.com/airGChat
#  16  http://twitter.com/airGChat
#  17  http://twitter.com/airGChat
#  18  http://twitter.com/airGChat
#  19  http://twitter.com/airGChat
#  20  http://twitter.com/airGChat
#  21  http://twitter.com/airGChat
#  22  http://twitter.com/airGChat
#
#                                                   text follower_data  \
#  0             justifications for 2 day censorship             4,420
#  3   broe if it s wasn t for airgchat ngabe asazani...         4,420
#  4   rt  big barn world sales will end today  make ...         4,420
#  5   turns out these douchebags  have been billing ...         4,420
#  6   big thx to  sponsors  2 kegs of beer   venue c...         4,420
#  7   follow me rt  lauryn hill shows up 3 hours lat...         4,420
#  8   countdown continues  just a half hour until th...         4,420
#  10   got the new breed of jobs   mobile advertisin...         4,420
#  11                                      in this snow          4,420
#  12              is looking for a jr  product manager          4,420
#  13  fas students  shape the future of the  enterta...         4,420
#  14  hey    have u seen details on our  event  disc...         4,420
#  16      so fantastic to see that proactive safety ...         4,420
#  17  learn how to start your mobile campaign at our...         4,420
#  18  no te creo rt    guess i ll get back on    oh ...         4,420
#  19      thank you to more of our nyc  sponsors                4,420
#  20  event  momovan  reaching mobile users is next ...         4,420
#  21                                                            4,420
#  22  free webinar on thursday    reaching the right...         4,420
#
#      following_data  polarity  subjectivity
#  0              137  0.000000      0.000000
#  3              137  0.000000      0.000000
#  4              137  0.250000      0.522222
#  5              137  0.000000      0.000000
#  6              137  0.000000      0.100000
#  7              137 -0.300000      0.600000
#  8              137  0.266667      0.383333
#  10             137  0.193182      0.652273
#  11             137  0.000000      0.000000
#  12             137  0.000000      0.000000
#  13             137  0.000000      0.125000
#  14             137  0.400000      0.400000
#  16             137  0.400000      0.900000
#  17             137  0.400000      0.800000
#  18             137  0.100000      0.150000
#  19             137  0.500000      0.500000
#  20             137  0.000000      0.000000
#  21             137  0.000000      0.000000
#  22             137  0.239683      0.467460  ,
#  'Akamai':                       account  \
#  0   http://twitter.com/Akamai
#  3   http://twitter.com/Akamai
#  4   http://twitter.com/Akamai
#  6   http://twitter.com/Akamai
#  7   http://twitter.com/Akamai
#  9   http://twitter.com/Akamai
#  12  http://twitter.com/Akamai
#  13  http://twitter.com/Akamai
#  15  http://twitter.com/Akamai
#  16  http://twitter.com/Akamai
#  18  http://twitter.com/Akamai
#  19  http://twitter.com/Akamai
#  21  http://twitter.com/Akamai
#  22  http://twitter.com/Akamai
#  24  http://twitter.com/Akamai
#  25  http://twitter.com/Akamai
#
#                                                   text  follower_data  \
#  0         always in my heart  que tingueu bons somnis       124000.0
#  3   in this article    s  goes over how to upload ...       124000.0
#  4   put web skimming attacks in a timeout    s  ex...       124000.0
#  6   don t get choked up by your firewall  eliminat...       124000.0
#  7       s dan petrillo explains why  complements e...       124000.0
#  9    take your marketing to the next level with   ...       124000.0
#  12  greater customization is now possible with the...       124000.0
#  13  the outlook and analysis of akamai technologie...       124000.0
#  15  a common myth is that wafs only gate traffic  ...       124000.0
#  16  in the latest patch tuesday report  we ll asse...       124000.0
#  18  join  at  and get insights on securing healthc...       124000.0
#  19  in this second session on april 17  we will co...       124000.0
#  21  this new report shows the massive range of cyb...       124000.0
#  22  edr and  might play on the same team  but they...       124000.0
#  24  build  secure  and deploy applications on   s ...       124000.0
#  25  meet julie  wellness program manager at akamai...       124000.0
#
#     following_data  polarity  subjectivity
#  0           2,943  0.000000      0.000000
#  3           2,943  0.500000      0.500000
#  4           2,943  0.000000      0.000000
#  6           2,943  0.000000      0.000000
#  7           2,943  0.000000      0.000000
#  9           2,943  0.250000      0.250000
#  12          2,943  0.250000      0.750000
#  13          2,943  0.500000      0.500000
#  15          2,943  0.066667      0.666667
#  16          2,943  0.333333      0.733333
#  18          2,943  0.000000      0.000000
#  19          2,943  0.300000      0.175000
#  21          2,943  0.209091      0.563636
#  22          2,943  0.000000      0.362500
#  24          2,943  0.300000      0.700000
#  25          2,943  0.000000      0.000000  ,
#  'alawarteam':                            account  \
#  0   https://twitter.com/alawarteam
#  3   https://twitter.com/alawarteam
#  4   https://twitter.com/alawarteam
#  6   https://twitter.com/alawarteam
#  8   https://twitter.com/alawarteam
#  10  https://twitter.com/alawarteam
#  12  https://twitter.com/alawarteam
#  13  https://twitter.com/alawarteam
#
#                                                   text  follower_data  \
#  0   here are the games i wishlisted for    you sho...            825
#  3   ahh  is out  we did it    120 000 words 45 cha...            825
#  4    it s follow friday  loving these     alchemists             825
#  6    they always run  become aidan  a three armed ...            825
#  8   hewwo beans  am live  thank you  for this copy...            825
#  10  to be honest  i d run too  hunt criminals acro...            825
#  12  yesterday during my birthday stream i was tota...            825
#  13  song of farca   a dark detective   hacker game...            825
#
#      following_data  polarity  subjectivity
#  0               37  0.000000      0.125000
#  3               37 -0.033333      0.538889
#  4               37  0.600000      0.950000
#  6               37 -0.050000      0.700000
#  8               37 -0.025974      0.567460
#  10              37  0.600000      0.900000
#  12              37  0.033333      0.550000
#  13              37 -0.238889      0.411111  ,
#  'americanexpress':                                account  \
#  2   http://twitter.com/americanexpress
#  4   http://twitter.com/americanexpress
#  5   http://twitter.com/americanexpress
#  7   http://twitter.com/americanexpress
#  8   http://twitter.com/americanexpress
#  10  http://twitter.com/americanexpress
#  11  http://twitter.com/americanexpress
#  12  http://twitter.com/americanexpress
#  13  http://twitter.com/americanexpress
#  14  http://twitter.com/americanexpress
#  16  http://twitter.com/americanexpress
#  17  http://twitter.com/americanexpress
#  18  http://twitter.com/americanexpress
#  20  http://twitter.com/americanexpress
#  21  http://twitter.com/americanexpress
#  23  http://twitter.com/americanexpress
#  24  http://twitter.com/americanexpress
#  26  http://twitter.com/americanexpress
#  27  http://twitter.com/americanexpress
#  28  http://twitter.com/americanexpress
#
#                                                   text  follower_data  \
#  2   new york city  have you heard the news  207 sh...       861600.0
#  4   looking for a weekend getaway that has somethi...       861600.0
#  5                our top 8 who s your pick for the          861600.0
#  7   daryl hall to join billy joel at american expr...       861600.0
#  8   any future hotel managers out there  now study...       861600.0
#  10  referral link  limited time promo 80k mr point...       861600.0
#  11  it should   has been stealing people s deposit...       861600.0
#  12                               red salute to heroes       861600.0
#  13  hope he enjoys the game like i will  i will be...       861600.0
#  14  wtffff  today i learned thar black american ex...       861600.0
#  16                                                ...       861600.0
#  17                                                          861600.0
#  18  se termina el mi rcoles y cae el sol con un tr...       861600.0
#  20  m  t o tiene la american express pero yo no te...       861600.0
#  21  we re delighted to announce the incredible  wi...       861600.0
#  23  apple   work podcast  business banking made di...       861600.0
#  24  american express platinum travel  one of the b...       861600.0
#  26  how american express found platinum success on...       861600.0
#  27  any members of the rob corps have the hilton h...       861600.0
#  28       is the american express trifecta worth it          861600.0
#
#      following_data  polarity  subjectivity
#  2              504  0.068182      0.377273
#  4              504  0.600000      0.350000
#  5              504  0.500000      0.500000
#  7              504  0.178571      0.285714
#  8              504  0.200000      0.462500
#  10             504 -0.035714      0.071429
#  11             504 -0.237500      0.187500
#  12             504  0.000000      0.000000
#  13             504  0.000000      0.650000
#  14             504 -0.255556      0.411111
#  16             504  0.000000      0.000000
#  17             504  0.000000      0.000000
#  18             504  0.025000      0.250000
#  20             504  0.000000      0.000000
#  21             504  0.392857      0.595238
#  23             504  0.146667      0.313333
#  24             504  0.500000      0.150000
#  26             504  0.150000      0.000000
#  27             504  0.000000      0.000000
#  28             504  0.150000      0.050000  ,
#  'ancestrydotcom':                               account  \
#  0   http://twitter.com/ancestrydotcom
#  3   http://twitter.com/ancestrydotcom
#  4   http://twitter.com/ancestrydotcom
#  5   http://twitter.com/ancestrydotcom
#  7   http://twitter.com/ancestrydotcom
#  8   http://twitter.com/ancestrydotcom
#  10  http://twitter.com/ancestrydotcom
#  11  http://twitter.com/ancestrydotcom
#  12  http://twitter.com/ancestrydotcom
#  13  http://twitter.com/ancestrydotcom
#  14  http://twitter.com/ancestrydotcom
#
#                                                   text  follower_data  \
#  0   elizabeth warren has not been this upset since...            488
#  3   white ppl hate poc but love fake tan  hate imm...            488
#  4   bossk ancestrydotcom results be like 36  32  2...            488
#  5   ep05 of  drops tomorrow am  in  i ll talk abou...            488
#  7   blackstone bought utah based ancestrydotcom fo...            488
#  8   just saw the ancestrydotcom commercial where t...            488
#  10  you just know there s a john redcorn out there...            488
#  11  yep  she spends a significant amount of her da...            488
#  12  yes me too  also when did we appoint ancestryd...            488
#  13  you got a bunch of low level initiates and sca...            488
#  14  check out   s ancestrydotcom page he obv is th...            488
#
#      following_data  polarity  subjectivity
#  0                1  0.000000      0.000000
#  3                1 -0.071429      0.714286
#  4                1 -0.125000      0.375000
#  5                1  0.000000      0.000000
#  7                1  0.000000      0.000000
#  8                1  0.000000      0.200000
#  10               1  0.000000      0.000000
#  11               1  0.187500      0.687500
#  12               1  0.000000      0.333333
#  13               1 -0.166667      0.475000
#  14               1  0.000000      0.000000  ,
#  'Animoto':                        account  \
#  0   http://twitter.com/Animoto
#  2   http://twitter.com/Animoto
#  3   http://twitter.com/Animoto
#  4   http://twitter.com/Animoto
#  5   http://twitter.com/Animoto
#  7   http://twitter.com/Animoto
#  9   http://twitter.com/Animoto
#  10  http://twitter.com/Animoto
#  11  http://twitter.com/Animoto
#
#                                                   text  follower_data  \
#  0   create beautiful photo and video slideshows wi...        62000.0
#  2   creating visually stunning social media videos...        62000.0
#  3   one of the instances where less is more mfs th...        62000.0
#  4   watch this video i made on   oceanside pier fa...        62000.0
#  5   discover a free and easy way to create stunnin...        62000.0
#  7   fala rapaziada  quase q eu esque o de postar e...        62000.0
#  9                                                            62000.0
#  10                                                           62000.0
#  11                                                           62000.0
#
#     following_data  polarity  subjectivity
#  0           5,211  0.850000      1.000000
#  2           5,211  0.383333      0.504167
#  3           5,211  0.166667      0.283333
#  4           5,211  0.000000      0.000000
#  5           5,211  0.444444      0.877778
#  7           5,211  0.000000      0.000000
#  9           5,211  0.000000      0.000000
#  10          5,211  0.000000      0.000000
#  11          5,211  0.000000      0.000000  ,
#  'antgroup':                         account  \
#  0  https://twitter.com/antgroup
#  3  https://twitter.com/antgroup
#
#                                                  text  follower_data  \
#  0  up next at the    learn from industry leaders ...        33200.0
#  3  chinese smartphone maker  and chinese fintech ...        33200.0
#
#     following_data  polarity  subjectivity
#  0              61  0.034091      0.113636
#  3              61  0.000000      0.333333  ,
#  'aol':                    account                                               text  \
#  0   http://twitter.com/aol              man  that aol chat room era was crazy
#  1   http://twitter.com/aol  the soft handed son of a nurse  eldest brother...
#  4   http://twitter.com/aol  this is where my gaming addiction started  aol...
#  5   http://twitter.com/aol  if feminism didn t exist he would invent femin...
#  6   http://twitter.com/aol                                    congratulations
#  8   http://twitter.com/aol  our dan  born and bred congratulations to one ...
#  9   http://twitter.com/aol  photo by                                      ...
#  10  http://twitter.com/aol                                60    70        ...
#  12  http://twitter.com/aol  congrats to all of the 2023 vogt educational  ...
#  13  http://twitter.com/aol  art of living vapi family feels blessed to hav...
#
#      follower_data following_data  polarity  subjectivity
#  0        161300.0          3,101    -0.600      0.900000
#  1        161300.0          3,101     0.100      0.350000
#  4        161300.0          3,101     0.000      0.000000
#  5        161300.0          3,101     0.000      0.000000
#  6        161300.0          3,101     0.000      0.000000
#  8        161300.0          3,101     0.000      0.000000
#  9        161300.0          3,101     0.000      0.000000
#  10       161300.0          3,101     0.000      0.000000
#  12       161300.0          3,101     0.515      0.625000
#  13       161300.0          3,101     0.000      0.166667  ,
#  'aplaceformom':                            account  \
#  0  http://twitter.com/aplaceformom
#  2  http://twitter.com/aplaceformom
#  3  http://twitter.com/aplaceformom
#
#                                                  text  follower_data  \
#  0  a simple act of kindness can profoundly impact...        13700.0
#  2  do not send your mother or any family member i...        13700.0
#  3  your most recent commercial sounds absolutely ...        13700.0
#
#    following_data  polarity  subjectivity
#  0          5,280  0.206667      0.711429
#  2          5,280 -0.115000      0.380000
#  3          5,280 -0.045536      0.416964  ,
#  'apnapaisa':                          account  \
#  0  https://twitter.com/apnapaisa
#  1  https://twitter.com/apnapaisa
#  3  https://twitter.com/apnapaisa
#  4  https://twitter.com/apnapaisa
#
#                                                  text  follower_data  \
#  0  wealth consists not in having great possession...            451
#  1  india aims to raise 15 43 trillion rupees   18...            451
#  3                                                               451
#  4  the reserve bank faqs on digital lending guide...            451
#
#     following_data  polarity  subjectivity
#  0              23  0.266667      0.316667
#  1              23  0.187500      0.275000
#  3              23  0.000000      0.000000
#  4              23  0.100000      0.275000  ,
#  'artdotcom':                           account  \
#  0   https://twitter.com/artdotcom
#  3   https://twitter.com/artdotcom
#  5   https://twitter.com/artdotcom
#  6   https://twitter.com/artdotcom
#  8   https://twitter.com/artdotcom
#  10  https://twitter.com/artdotcom
#  11  https://twitter.com/artdotcom
#  12  https://twitter.com/artdotcom
#
#                                                   text  follower_data  \
#  0   arguably my favorite ring cover  seeing the or...        27800.0
#  3   what are you waiting for      shop our sales  ...        27800.0
#  5   just noticed that  shipped my order via fedex ...        27800.0
#  6   i ve never seen this photo posted by the  of t...        27800.0
#  8   ordered a framed 38 x26  creation of david det...        27800.0
#  10  photo source   hassler william davis collectio...        27800.0
#  11  went to the  party at    i wanted everything i...        27800.0
#  12    outting the team first  defines for me the d...        27800.0
#
#      following_data  polarity  subjectivity
#  0              654  0.625000      0.916667
#  3              654  0.000000      0.000000
#  5              654  0.437500      0.625000
#  6              654  0.000000      0.000000
#  8              654  0.000000      0.000000
#  10             654  0.068182      0.227273
#  11             654  0.210000      0.630000
#  12             654  0.358889      0.624444  ,
#  'askdotcom':                         account  \
#  0  http://twitter.com/askdotcom
#  3  http://twitter.com/askdotcom
#  4  http://twitter.com/askdotcom
#  5  http://twitter.com/askdotcom
#  6  http://twitter.com/askdotcom
#
#                                                  text  follower_data  \
#  0            steve irwin would have turned 61 today         58700.0
#  3  sevgilimkolik yani sevgilisi d   nda hi  bir  ...        58700.0
#  4                   yo     when s jeevesai droppin          58700.0
#  5  ai opens the door for a rebrand of ask jeeves ...        58700.0
#  6  i felt it was strongly plotted but a strange s...        58700.0
#
#    following_data  polarity  subjectivity
#  0          3,332   0.00000      0.000000
#  3          3,332   0.00000      0.000000
#  4          3,332   0.00000      0.000000
#  5          3,332   0.00000      0.000000
#  6          3,332   0.07381      0.416667  ,
#  'ATT':                    account                                               text  \
#  0   http://twitter.com/ATT  nostalgic tech bracket  welcome to the final f...
#  1   http://twitter.com/ATT            round 3  game 2 iphone 5c v  ipod touch
#  2   http://twitter.com/ATT  round 3  game 1 blackberry pearl v  motorola razr
#  3   http://twitter.com/ATT                  please step into our phone booth
#  4   http://twitter.com/ATT             round 1  game 5 iphone 3g v  iphone 5c
#  5   http://twitter.com/ATT      round 1  game 4 lg chocolate v  motorola razr
#  6   http://twitter.com/ATT       round 1  game 3 corded phone v  rotary phone
#  7   http://twitter.com/ATT     round 1  game 2 nokia 3310 v  blackberry pearl
#  8   http://twitter.com/ATT                 round 1  game 1 car phone v  pager
#  9   http://twitter.com/ATT  bracket season is finally upon us  allow us to...
#  10  http://twitter.com/ATT
#  11  http://twitter.com/ATT       tell us who your  team is using only emojis
#  12  http://twitter.com/ATT                    this ios ux brings it all back
#  13  http://twitter.com/ATT  in honor of at t s birthday  we re throwing it...
#  14  http://twitter.com/ATT  who s taking home the  trophy  predictions bel...
#  15  http://twitter.com/ATT                 tweets as inspirational messages
#  16  http://twitter.com/ATT  in slc this weekend for   find us at  crossove...
#  17  http://twitter.com/ATT  epic starting     now  the  galaxy s23 series ...
#  18  http://twitter.com/ATT               you know where to find us on 10 20
#  19  http://twitter.com/ATT         pov  hearing the operator instead of siri
#  20  http://twitter.com/ATT
#  21  http://twitter.com/ATT  ever wonder what it would be like to ball like...
#  22  http://twitter.com/ATT  3 epic phones for your 2023 adventures   galax...
#  23  http://twitter.com/ATT                                        meet cream
#  24  http://twitter.com/ATT                              introducing lavender
#  25  http://twitter.com/ATT  3 new phones  3 new colors  meet the new  gala...
#  26  http://twitter.com/ATT  brb packing our golf bags for the  this week  ...
#  27  http://twitter.com/ATT  a little  love incoming  enter for a chance to...
#  28  http://twitter.com/ATT               spoiler alert  new  coming soooooon
#  29  http://twitter.com/ATT     tag the friend who texts you just to check in
#  30  http://twitter.com/ATT              ok    they re mad  end of discussion
#  31  http://twitter.com/ATT  tag a friend and tell them why they re the ult...
#  32  http://twitter.com/ATT  the phone was invented by alexander graham bel...
#  33  http://twitter.com/ATT         tell us what s for breakfast using emojis
#  34  http://twitter.com/ATT   to a time when our technology took up more sp...
#
#      follower_data  following_data  polarity  subjectivity
#  0        908700.0             249  0.100000      0.966667
#  1        908700.0             249 -0.300000      0.400000
#  2        908700.0             249 -0.300000      0.400000
# ...
#  0   funny hangman homework notebook is 15  off wit...        60700.0
#  3   dauphin island houses  alabama postcard these ...        60700.0
#  5   bohemian bound lighting your way from zazzle  ...        60700.0
#  6                                                            60700.0
#  7                  a slice of pi numbers poster  via         60700.0
#  9          usa flag pattern flash drive  via                 60700.0
#  10     american flag flip flops red white and blue           60700.0
#  11  super mom  mom s gift ideas  gift for mom  cus...        60700.0
#
#      following_data  polarity  subjectivity
#  0              858  0.250000      1.000000
#  3              858  0.450000      0.650000
#  5              858  0.333333      0.416667
#  6              858  0.000000      0.000000
#  7              858  0.000000      0.000000
#  9              858  0.000000      0.000000
#  10             858  0.000000      0.025000
#  11             858  0.333333      0.666667  ,
#  'Zello':                      account  \
#  0   http://twitter.com/Zello
#  1   http://twitter.com/Zello
#  4   http://twitter.com/Zello
#  5   http://twitter.com/Zello
#  6   http://twitter.com/Zello
#  7   http://twitter.com/Zello
#  8   http://twitter.com/Zello
#  9   http://twitter.com/Zello
#  10  http://twitter.com/Zello
#  11  http://twitter.com/Zello
#  12  http://twitter.com/Zello
#  13  http://twitter.com/Zello
#  14  http://twitter.com/Zello
#  15  http://twitter.com/Zello
#  16  http://twitter.com/Zello
#  17  http://twitter.com/Zello
#  18  http://twitter.com/Zello
#  20  http://twitter.com/Zello
#  21  http://twitter.com/Zello
#  22  http://twitter.com/Zello
#
#                                                   text  follower_data  \
#  0   tomorrow is a special school holiday  it was d...        34300.0
#  1   don t be too naive  gotta always see it they b...        34300.0
#  4     club net this evening on zello  marts 144 650          34300.0
#  5    hey guys  guess what  it s almost time for zello        34300.0
#  6   most of the people who died during the 1918 pl...        34300.0
#  7                     senior product manager at zello        34300.0
#  8                                       iv and greeks        34300.0
#  9                           hook up that zello radio         34300.0
#  10  she s getting creamed  i can t even keep up wi...        34300.0
#  11  mom used to make concord grape jelly  it s ver...        34300.0
#  12  bullies are losers and they are a couple of lo...        34300.0
#  13                       it s only the second quarter        34300.0
#  14  because he goes on and on and on  all for mone...        34300.0
#  15                   not according to desanctimonious        34300.0
#  16               this archbishop sounds like lucifer         34300.0
#  17  dont think so because there is a branched rive...        34300.0
#  18                where is he  did he go into hiding         34300.0
#  20      desc rguense zello as  los puedo molestar            34300.0
#  21  a real leader would take a position and stand ...        34300.0
#  22                                 it s fake  ai pics        34300.0
#
#     following_data  polarity  subjectivity
#  0           4,533  0.195238      0.319048
#  1           4,533 -0.300000      1.000000
#  4           4,533  0.000000      0.000000
#  5           4,533  0.000000      0.000000
#  6           4,533  0.500000      0.500000
#  7           4,533  0.000000      0.000000
#  8           4,533  0.000000      0.000000
#  9           4,533  0.000000      0.000000
#  10          4,533  0.000000      0.000000
#  11          4,533  0.450000      0.450000
#  12          4,533 -0.200000      0.200000
#  13          4,533  0.000000      0.500000
#  14          4,533 -0.388889      0.833333
#  15          4,533  0.000000      0.000000
#  16          4,533  0.000000      0.000000
#  17          4,533  0.000000      0.000000
#  18          4,533  0.000000      0.000000
#  20          4,533  0.000000      0.000000
#  21          4,533 -0.012500      0.308333
#  22          4,533 -0.500000      1.000000  ,
#  'zimbra':                       account  \
#  0   http://twitter.com/zimbra
#  1   http://twitter.com/zimbra
#  2   http://twitter.com/zimbra
#  3   http://twitter.com/zimbra
#  4   http://twitter.com/zimbra
#  5   http://twitter.com/zimbra
#  6   http://twitter.com/zimbra
#  7   http://twitter.com/zimbra
#  8   http://twitter.com/zimbra
#  9   http://twitter.com/zimbra
#  10  http://twitter.com/zimbra
#  11  http://twitter.com/zimbra
#  12  http://twitter.com/zimbra
#  13  http://twitter.com/zimbra
#  14  http://twitter.com/zimbra
#  15  http://twitter.com/zimbra
#  16  http://twitter.com/zimbra
#  17  http://twitter.com/zimbra
#  18  http://twitter.com/zimbra
#  19  http://twitter.com/zimbra
#  20  http://twitter.com/zimbra
#  21  http://twitter.com/zimbra
#  22  http://twitter.com/zimbra
#  23  http://twitter.com/zimbra
#  24  http://twitter.com/zimbra
#  25  http://twitter.com/zimbra
#  26  http://twitter.com/zimbra
#  27  http://twitter.com/zimbra
#  28  http://twitter.com/zimbra
#
#                                                   text  follower_data  \
#  0   as part of our ongoing commitment to customer ...        10500.0
#  1   new zimbra patches  9 0 0 patch 31   8 8 15 pa...        10500.0
#  2   unsure if your current email data processor pr...        10500.0
#  3     zimbra patches  9 0 0 patch 31   8 8 15 patc...        10500.0
#  4     a milter for using spamhaus hbl with zimbra ...        10500.0
#  5   zimbra system admins   our 3 day training star...        10500.0
#  6   zimbra system admins     this training is for ...        10500.0
#  7   enroll now  it is almost too late  the 1 day z...        10500.0
#  8   in just 2 weeks     zimbra system administrati...        10500.0
#  9   inscrivez vous avant qu il ne soit trop tard  ...        10500.0
#  10  admins syst me zimbra  formation de 3 jours co...        10500.0
#  11  spaces limited  enroll now for the 1 day zimbr...        10500.0
#  12  inscrivez vous avant qu il ne soit trop tard  ...        10500.0
#  13  zimbra system admins   our 3 day training star...        10500.0
#  14  part 3 is coming    zimbra email security webi...        10500.0
#  15    learn how to customize the navigation in the...        10500.0
#  16    learn how to set the sensitivity header in z...        10500.0
#  17  zimbra system admins     this training is for ...        10500.0
#  18    learn how to use the anyframe zimlet to inte...        10500.0
#  19  zimbra system admin 27 29 de abril voc  vai ap...        10500.0
#  20    enable dane for incoming email in zimbra  da...        10500.0
#  21  zimbra system admins     this training is for ...        10500.0
#  22    colocity s precision controlled environment ...        10500.0
#  23  zimbra system admins     this training is for ...        10500.0
#  24  in just 2 weeks     zimbra system administrati...        10500.0
#  25  do you support zimbra  check out the 1 day zim...        10500.0
#  26  enroll now  it is almost too late  the 1 day z...        10500.0
#  27   reserva un hueco en tu calendario el 3 de mar...        10500.0
#  28  zimbra system admins   our 3 day training star...        10500.0
#
#     following_data  polarity  subjectivity
#  0           2,716  0.393750      0.412500
#  1           2,716  0.068182      0.227273
#  2           2,716  0.375000      0.475000
#  3           2,716  0.250000      0.250000
#  4           2,716  0.500000      0.500000
#  5           2,716  0.284091      0.431250
#  6           2,716  0.045455      0.475000
#  7           2,716  0.012121      0.433333
#  8           2,716  0.136364      0.500000
#  9           2,716  0.000000      0.000000
#  10          2,716 -0.800000      1.000000
#  11          2,716  0.064286      0.171429
#  12          2,716  0.000000      0.000000
#  13          2,716  0.284091      0.431250
#  14          2,716  0.000000      0.000000
#  15          2,716  0.100000      0.400000
#  16          2,716  0.000000      0.000000
#  17          2,716  0.045455      0.475000
#  18          2,716  0.100000      0.150000
#  19          2,716  0.000000      0.000000
#  20          2,716  0.100000      0.400000
#  21          2,716  0.045455      0.475000
#  22          2,716  0.686667      0.346667
#  23          2,716  0.068182      0.312500
#  24          2,716  0.136364      0.500000
#  25          2,716  0.168182      0.350000
#  26          2,716  0.012121      0.433333
#  27          2,716  0.000000      0.000000
#  28          2,716  0.284091      0.431250  ,
#  'zoho':                     account  \
#  0   http://twitter.com/zoho
#  1   http://twitter.com/zoho
#  2   http://twitter.com/zoho
#  5   http://twitter.com/zoho
#  6   http://twitter.com/zoho
#  8   http://twitter.com/zoho
#  10  http://twitter.com/zoho
#  12  http://twitter.com/zoho
#  13  http://twitter.com/zoho
#  14  http://twitter.com/zoho
#  16  http://twitter.com/zoho
#  17  http://twitter.com/zoho
#  19  http://twitter.com/zoho
#  21  http://twitter.com/zoho
#  23  http://twitter.com/zoho
#  25  http://twitter.com/zoho
#  26  http://twitter.com/zoho
#
#                                                   text  follower_data  \
#  0   a company is doing  1 billion in revenue with ...        91800.0
#  1   zoho ceo getting the taste of indian laws  fli...        91800.0
#  2   the carefully constructed myth around zoho fou...        91800.0
#  5   today in tech3 breaking  meta is reducing its ...        91800.0
#  6   zoho ceo s estranged wife accuses him of fraud...        91800.0
#  8   the soon to be ex wife of zoho cofounder and c...        91800.0
#  10  think globally act locally  have your business...        91800.0
#  12  2  there is no law of nature that says softwar...        91800.0
#  13                                          article 6        91800.0
#  14  profitable unicorns   unicorns which made prof...        91800.0
#  16  discovering all your zoho applications  you do...        91800.0
#  17  zoho one consulting services book your free co...        91800.0
#  19    radha vembu  the sister of zoho ceo and co f...        91800.0
#  21  zoho offers different communications channel i...        91800.0
#  23    save this image for later   create a landing...        91800.0
#  25  one of the most frequently cited complaints ab...        91800.0
#  26  bug tracking is logging and monitoring errors ...        91800.0
#
#      following_data  polarity  subjectivity
#  0              112  0.000000      0.000000
#  1              112  0.333333      0.700000
#  2              112 -0.200000      0.500000
#  5              112  0.250000      0.500000
#  6              112  0.000000      0.000000
#  8              112  0.528571      0.735714
#  10             112  0.000000      0.000000
#  12             112  0.259206      0.541111
#  13             112  0.000000      0.000000
#  14             112  0.000000      0.000000
#  16             112  0.500000      0.500000
#  17             112  0.400000      0.800000
#  19             112  0.000000      0.000000
#  21             112  0.050000      0.300000
#  23             112  0.000000      0.000000
#  25             112  0.233333      0.300000
#  26             112  0.600000      0.300000  ,
#  'ZoomInfo':                         account  \
#  0   http://twitter.com/ZoomInfo
#  1   http://twitter.com/ZoomInfo
#  2   http://twitter.com/ZoomInfo
#  3   http://twitter.com/ZoomInfo
#  4   http://twitter.com/ZoomInfo
#  5   http://twitter.com/ZoomInfo
#  6   http://twitter.com/ZoomInfo
#  7   http://twitter.com/ZoomInfo
#  8   http://twitter.com/ZoomInfo
#  9   http://twitter.com/ZoomInfo
#  10  http://twitter.com/ZoomInfo
#  11  http://twitter.com/ZoomInfo
#  12  http://twitter.com/ZoomInfo
#  13  http://twitter.com/ZoomInfo
#  14  http://twitter.com/ZoomInfo
#  15  http://twitter.com/ZoomInfo
#  16  http://twitter.com/ZoomInfo
#  17  http://twitter.com/ZoomInfo
#  18  http://twitter.com/ZoomInfo
#  19  http://twitter.com/ZoomInfo
#  20  http://twitter.com/ZoomInfo
#  21  http://twitter.com/ZoomInfo
#  22  http://twitter.com/ZoomInfo
#  23  http://twitter.com/ZoomInfo
#  24  http://twitter.com/ZoomInfo
#  25  http://twitter.com/ZoomInfo
#  26  http://twitter.com/ZoomInfo
#  27  http://twitter.com/ZoomInfo
#
#                                                   text  follower_data  \
#  0   check out some of the gpt integration features...        24200.0
#  1    4 4  we have seven more tips waiting for you ...        24200.0
#  2    3 4  say less  nothing is scarier than a lull...        24200.0
#  3    2 4  find your flow  some of us need 30 open ...        24200.0
#  4   rolling to the end of today s  session  we hav...        24200.0
#  5   3 1 at 11 00 am est    our senior director of ...        24200.0
#  6   find us at booth  for a chance to win some cho...        24200.0
#  7   going to 2023    mark your calendars 2 28 at 3...        24200.0
#  8        too good to be true  try it out for yourself        24200.0
#  9     all recruiters tired of how long it takes to...        24200.0
#  10  but wait  there s more tues  feb  28 at 6 30 p...        24200.0
#  11  reasons why we  check out their detailed break...        24200.0
#  12   b2b marketers  version of the chicken or the ...        24200.0
#  13  for more tips on outbound outreach check out o...        24200.0
#  14  the cta shut up and drive the behavior you re ...        24200.0
#  15  the body you ve hooked  em  now reel  em in  s...        24200.0
#  16  the hook a good hook is something insightful a...        24200.0
#  17  you can use many channels for outbound prospec...        24200.0
#  18  you ve heard of outbound prospecting but how d...        24200.0
#  19  things to add to your data quality checklist v...        24200.0
#  20  lou wolf  vp of sales at zoominfo  survived th...        24200.0
#  21   quiet quitting    the term that s taken socia...        24200.0
#  22  hear how ken confronts the stereotypes of toda...        24200.0
#  23   hey siri  play  enter sandman  by metallica  ...        24200.0
#  24  how to clean up your  view for a cleaner and m...        24200.0
#  25  do your sales and marketing teams still need t...        24200.0
#  26  80  of consumers are more likely to buy from b...        24200.0
#  27  b2b display ad mistakes are costly   even if y...        24200.0
#
#     following_data  polarity  subjectivity
#  0           1,528  0.000000      0.000000
#  1           1,528  0.500000      0.750000
#  2           1,528 -0.083333      0.283333
#  3           1,528  0.068182      0.500000
#  4           1,528  0.322222      0.344444
#  5           1,528  0.000000      0.000000
#  6           1,528  0.592857      0.442857
#  7           1,528  0.050000      0.050000
#  8           1,528  0.525000      0.625000
#  9           1,528 -0.225000      0.550000
#  10          1,528  0.292857      0.314286
#  11          1,528  0.266667      0.450000
#  12          1,528 -0.016667      0.627778
#  13          1,528  0.500000      0.700000
#  14          1,528  0.075000      0.548095
#  15          1,528  0.033333      0.066667
#  16          1,528  0.233333      0.500000
#  17          1,528  0.587500      0.712500
#  18          1,528  0.000000      0.000000
#  19          1,528 -0.166667      0.166667
#  20          1,528  0.000000      0.050000
#  21          1,528  0.056667      0.316667
#  22          1,528  1.000000      0.300000
#  23          1,528  1.000000      1.000000
#  24          1,528  0.433333      0.600000
#  25          1,528 -0.450000      0.600000
#  26          1,528  0.420000      0.660000
#  27          1,528 -0.500000      0.900000  }

# %%
# Create single dataframe for all companies

company = [] 
account = []
followers = []
following = []
polarity = []
subjectivity = []

for key, val in data_c.items():
    for item in val['follower_data']:
        followers.append(item)
        break
    for item in val['following_data']:
        following.append(item)
        break
    for item in val['account']:
        account.append(item)
        break
    company.append(key)
    polarity.append(val['polarity'].mean())
    subjectivity.append(val['subjectivity'].mean())

enrich_df = pd.DataFrame(list(zip(company, following, followers, polarity, subjectivity, account)),
                         columns=  ['company_name','following','followers','polarity',
                         'subjectivity','account'])

# %%
# View the final dataset
enrich_df
# Out:
#       company_name following followers  polarity  subjectivity  \
# 0                      2,012     6,811  0.036111      0.184722
# 1    1NorthEnlight         7         5  0.441667      0.705556
# 2          23andMe     6,814   92900.0  0.094235      0.351383
# 3            4INFO     2,061     2,109  0.375000      0.750000
# 4      A123Systems       185     1,844  0.012121      0.284848
# ..             ...       ...       ...       ...           ...
# 322         zappos       858   60700.0  0.086145      0.263922
# 323         Zazzle     4,533   34300.0  0.170833      0.344792
# 324          Zello     2,716   10500.0 -0.012808      0.255536
# 325         zimbra       112   91800.0  0.115857      0.330372
# 326           zoho     1,528   24200.0  0.173791      0.304519
#
#                                   account
# 0    https://twitter.com/jellyfishglobal/
# 1        http://twitter.com/1NorthEnlight
# 2              http://twitter.com/23andMe
# 3                http://twitter.com/4INFO
# 4          http://twitter.com/A123Systems
# ..                                    ...
# 322             http://twitter.com/Zazzle
# 323              http://twitter.com/Zello
# 324             http://twitter.com/zimbra
# 325               http://twitter.com/zoho
# 326           http://twitter.com/ZoomInfo
#
# [327 rows x 6 columns]

# %%
# Save the dataset
enrich_df.to_csv('enrichdata.csv',index=False)
