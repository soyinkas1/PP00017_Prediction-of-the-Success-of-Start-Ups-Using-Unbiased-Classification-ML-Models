# %%
# Import python libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly

# %% [markdown]
# ### Explore all the files for high level details

# %%
# Read the checksum.csv file and check the top 5 rows
checksum = pd.read_csv('data/checksum.csv')
checksum.head(17)
# Out:
#                          filename                previous_check_sum  \
# 0               organizations.csv  ab7434773d09791639efaa57b43cd238
# 1   organization_descriptions.csv  df8db645aa7d016e79e2c5e689e070c3
# 2                      people.csv  ed8f9aa4c94ac208d73a359c318964b3
# 3         people_descriptions.csv  da27e27cd9d049a696222712219253d5
# 4                     degrees.csv  33fac1f8284d441eba45ccc370432f60
# 5              funding_rounds.csv  58264bc245d9b7db937959131f436d6a
# 6                 investments.csv  f72dd4ad5e7c08e085203745e4e0b095
# 7         investment_partners.csv  96f35d3f3b80a7207bc6e690af7c7ea8
# 8                   investors.csv  2c9b919297ade519be99465debcbe4d7
# 9                       funds.csv  bce8567b5c3c0f5daf3cd766be740ade
# 10               acquisitions.csv  d94460c13469c220f577e019963abf3e
# 11                       ipos.csv  2ef2367ee49133ec1a099af7e3b568d4
# 12                     events.csv  fa4f225a26bca0b3136f66738e7f9d59
# 13          event_appearances.csv  cbd0212399ef6820f3e83319adcf9db4
# 14                       jobs.csv  09d078254130e7324e19f37fadb4697d
# 15            category_groups.csv  6cb4931a59492c1706b849ca35c8f75d
# 16                org_parents.csv  75c4ea69173e9b37e5b1bc83c39491b8
#
#                    current_check_sum
# 0   0ebd453c5e28e6e8e32e2514901655ca
# 1   e0bae9d153078ee170f7d52f174e164e
# 2   c4acaadd962b739aaf0d05609b96c4d2
# 3   84660abcd042346b0ad0d6c3e4a76344
# 4   e700b99dd553012117dc92c60a248269
# 5   491d40b01d6b2013acf2b60b056d6a00
# 6   83a90f5d55480049214337f37fcd7501
# 7   2c29da848534d3605eb819e754a86581
# 8   cb944c36b3bf6215cdaee012add8c685
# 9   25918138f777a587f9ca349e45f16680
# 10  bcb6e33d1281cbb11e12211ce7961c8f
# 11  47a8e25bb27cc10490ab316c53558342
# 12  89c34e1e8450803f9a25168ab6fa9811
# 13  4368049971ed8cc98543c927323ca2c6
# 14  3b575c07cd1dd2d474ca1792352e5906
# 15  6cb4931a59492c1706b849ca35c8f75d
# 16  f91e41e51c290b1969b10833bdba1a57

# %%
# Get the general information on the dataset
checksum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            17 non-null     object
#  1   previous_check_sum  17 non-null     object
#  2   current_check_sum   17 non-null     object
# dtypes: object(3)
# memory usage: 536.0+ bytes

# %%
# Read the organizations.csv file and check the top 5 rows
organizations = pd.read_csv('Crunchbase Data/organizations.csv')
organizations.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at  \
# 0  194947.0  2007-05-25 13:51:27  2022-03-07 05:47:35
# 1    6999.0  2007-05-26 02:30:28  2022-11-30 00:28:26
# 2   26624.0  2007-05-26 03:03:23  2018-12-10 10:09:14
# 3   49970.0  2007-05-26 03:21:34  2022-07-19 01:45:23
# 4      13.0  2007-05-26 04:22:15  2022-08-05 13:19:05
#
#                    legal_name             roles  ...           phone  \
# 0                         NaN           company  ...    206-859-6300
# 1  Zoho Corporation Pvt. Ltd.  investor,company  ...  044 - 67447070
# 2          Digg Holdings, LLC           company  ...    877-342-7222
# 3                         NaN  investor,company  ...    650.482.2500
# 4        Meta Platforms, Inc.  investor,company  ...             NaN
#
#                              facebook_url  \
# 0       https://www.facebook.com/Wetpaint
# 1            http://www.facebook.com/zoho
# 2            http://www.facebook.com/digg
# 3  http://www.facebook.com/OmidyarNetwork
# 4           https://www.facebook.com/Meta
#
#                             linkedin_url                        twitter_url  \
# 0                                    NaN     https://twitter.com/wetpainttv
# 1  https://www.linkedin.com/company/zoho            http://twitter.com/zoho
# 2   http://www.linkedin.com/company/digg            http://twitter.com/digg
# 3  http://www.linkedin.com/company/22806  http://twitter.com/OmidyarNetwork
# 4  https://www.linkedin.com/company/meta           https://twitter.com/Meta
#
#                                             logo_url    alias1  \
# 0  https://res.cloudinary.com/crunchbase-producti...       NaN
# 1  https://res.cloudinary.com/crunchbase-producti...       NaN
# 2  https://res.cloudinary.com/crunchbase-producti...       NaN
# 3  https://res.cloudinary.com/crunchbase-producti...       NaN
# 4  https://res.cloudinary.com/crunchbase-producti...  Facebook
#
#            alias2 alias3 primary_role num_exits
# 0             NaN    NaN      company       NaN
# 1             NaN    NaN      company       2.0
# 2             NaN    NaN      company       NaN
# 3             NaN    NaN     investor      55.0
# 4  Facebook, Inc.    NaN      company       1.0
#
# [5 rows x 41 columns]

# %%
# Get the general information on the dataset
organizations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597998 entries, 0 to 2597997
# Data columns (total 41 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   uuid                         object
#  1   name                         object
#  2   type                         object
#  3   permalink                    object
#  4   cb_url                       object
#  5   rank                         float64
#  6   created_at                   object
#  7   updated_at                   object
#  8   legal_name                   object
#  9   roles                        object
#  10  domain                       object
#  11  homepage_url                 object
#  12  country_code                 object
#  13  state_code                   object
#  14  region                       object
#  15  city                         object
#  16  address                      object
#  17  postal_code                  object
#  18  status                       object
#  19  short_description            object
#  20  category_list                object
#  21  category_groups_list         object
#  22  num_funding_rounds           float64
#  23  total_funding_usd            float64
#  24  total_funding                float64
#  25  total_funding_currency_code  object
#  26  founded_on                   object
#  27  last_funding_on              object
#  28  closed_on                    object
#  29  employee_count               object
#  30  email                        object
#  31  phone                        object
#  32  facebook_url                 object
#  33  linkedin_url                 object
#  34  twitter_url                  object
#  35  logo_url                     object
#  36  alias1                       object
#  37  alias2                       object
#  38  alias3                       object
#  39  primary_role                 object
#  40  num_exits                    float64
# dtypes: float64(5), object(36)
# memory usage: 812.7+ MB

# %%
# Read the organization_descriptions.csv file and check the top 5 rows
organization_descriptions = pd.read_csv('data/organization_descriptions.csv')
organization_descriptions.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at  \
# 0  194947.0  2007-05-25 13:51:27  2022-03-07 05:47:35
# 1    6999.0  2007-05-26 02:30:28  2022-11-30 00:28:26
# 2   26624.0  2007-05-26 03:03:23  2018-12-10 10:09:14
# 3   49970.0  2007-05-26 03:21:34  2022-07-19 01:45:23
# 4      13.0  2007-05-26 04:22:15  2022-08-05 13:19:05
#
#                                          description
# 0  Wetpaint is a technology platform company that...
# 1  Zoho offers a suite of business, collaboration...
# 2  Digg Inc. operates a website that enables its ...
# 3  Pierre Omidyar, the founder of eBay, and his w...
# 4  Meta is a social technology company that enabl...

# %%
# Get the general information on the dataset
organization_descriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280208 entries, 0 to 1280207
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   uuid         1280208 non-null  object
#  1   name         1280202 non-null  object
#  2   type         1280208 non-null  object
#  3   permalink    1280194 non-null  object
#  4   cb_url       1280195 non-null  object
#  5   rank         1279654 non-null  float64
#  6   created_at   1280208 non-null  object
#  7   updated_at   1280208 non-null  object
#  8   description  1280197 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 87.9+ MB

# %%
# Read the people.csv file and check the top 5 rows
people = pd.read_csv('data/people.csv')
people.head()
# Out:
#                                    uuid            name    type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna  person
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig  person
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne  person
#
#         permalink                                            cb_url      rank  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   30872.0
# 1  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  731097.0
# 2    raju-vegesna    https://www.crunchbase.com/person/raju-vegesna   11465.0
# 3       ian-wenig       https://www.crunchbase.com/person/ian-wenig  472935.0
# 4      owen-byrne      https://www.crunchbase.com/person/owen-byrne  638331.0
#
#             created_at           updated_at first_name last_name  ...  \
# 0  2007-05-25 14:03:54  2022-06-27 08:59:09        Ben   Elowitz  ...
# 1  2007-05-25 14:04:16  2018-02-12 23:14:37      Kevin  Flaherty  ...
# 2  2007-05-26 02:33:03  2022-02-24 12:24:29       Raju   Vegesna  ...
# 3  2007-05-26 02:34:53  2021-03-23 10:25:04        Ian     Wenig  ...
# 4  2007-05-26 03:06:45  2022-04-08 19:52:41       Owen     Byrne  ...
#
#   state_code      region           city        featured_job_organization_uuid  \
# 0         WA  Washington        Seattle  1d845b32-7d80-47af-957d-78ccbeeaefb6
# 1         WA  Washington  Mercer Island  789e5e4d-0c90-d06e-92a0-b800b461c3da
# 2         CA  California  San Francisco  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 3        NaN         NaN            NaN  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 4         CA  California  Mountain View                                   NaN
#
#   featured_job_organization_name       featured_job_title  \
# 0                      Zeitworks               Co-Founder
# 1                       DRSmedia              Team Member
# 2                           Zoho         Chief Evangelist
# 3                           Zoho  VP Business Development
# 4                            NaN                      NaN
#
#                       facebook_url  \
# 0  http://www.facebook.com/elowitz
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                                        linkedin_url  \
# 0               https://www.linkedin.com/in/elowitz
# 1          http://www.linkedin.com/in/kevinflaherty
# 2  https://www.linkedin.com/in/raju-vegesna-78a6541
# 3                                               NaN
# 4               https://www.linkedin.com/in/ojbyrne
#
#                     twitter_url  \
# 0    http://twitter.com/elowitz
# 1    https://twitter.com/tallkp
# 2     https://twitter.com/rajuv
# 3                           NaN
# 4  http://twitter.com/owenbyrne
#
#                                             logo_url
# 0  https://res.cloudinary.com/crunchbase-producti...
# 1  https://res.cloudinary.com/crunchbase-producti...
# 2  https://res.cloudinary.com/crunchbase-producti...
# 3  https://res.cloudinary.com/crunchbase-producti...
# 4  https://res.cloudinary.com/crunchbase-producti...
#
# [5 rows x 22 columns]

# %%
# Get the general information on the dataset
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631627 entries, 0 to 1631626
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   uuid                            1631627 non-null  object
#  1   name                            1631627 non-null  object
#  2   type                            1631627 non-null  object
#  3   permalink                       1631617 non-null  object
#  4   cb_url                          1631617 non-null  object
#  5   rank                            1629253 non-null  float64
#  6   created_at                      1631627 non-null  object
#  7   updated_at                      1631627 non-null  object
#  8   first_name                      1631572 non-null  object
#  9   last_name                       1631536 non-null  object
#  10  gender                          1570945 non-null  object
#  11  country_code                    1251117 non-null  object
#  12  state_code                      635326 non-null   object
#  13  region                          1147194 non-null  object
#  14  city                            1100673 non-null  object
#  15  featured_job_organization_uuid  1042541 non-null  object
#  16  featured_job_organization_name  1042540 non-null  object
#  17  featured_job_title              1042524 non-null  object
#  18  facebook_url                    150703 non-null   object
#  19  linkedin_url                    1227473 non-null  object
#  20  twitter_url                     248112 non-null   object
#  21  logo_url                        1189603 non-null  object
# dtypes: float64(1), object(21)
# memory usage: 273.9+ MB

# %%
# Read the people_descriptions.csv file and check the top 5 rows
people_descriptions = pd.read_csv('data/people_descriptions.csv')
people_descriptions.head()
# Out:
#                                    uuid            name    type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz  person
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  person
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna  person
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig  person
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne  person
#
#         permalink                                            cb_url      rank  \
# 0     ben-elowitz     https://www.crunchbase.com/person/ben-elowitz   30872.0
# 1  kevin-flaherty  https://www.crunchbase.com/person/kevin-flaherty  731097.0
# 2    raju-vegesna    https://www.crunchbase.com/person/raju-vegesna   11465.0
# 3       ian-wenig       https://www.crunchbase.com/person/ian-wenig  472935.0
# 4      owen-byrne      https://www.crunchbase.com/person/owen-byrne  638331.0
#
#             created_at           updated_at  \
# 0  2007-05-25 14:03:54  2022-06-27 08:59:09
# 1  2007-05-25 14:04:16  2018-02-12 23:14:37
# 2  2007-05-26 02:33:03  2022-02-24 12:24:29
# 3  2007-05-26 02:34:53  2021-03-23 10:25:04
# 4  2007-05-26 03:06:45  2022-04-08 19:52:41
#
#                                          description
# 0  Ben Elowitz is a Member Board Of Directors at ...
# 1  Brand development, creative agency management,...
# 2  Raju is an evangelist for Zoho and is one of t...
# 3  Ian Wenig has more then twenty years experienc...
# 4  Legend has it that Owen Byrne was hired by [Di...

# %%
# Get the general information on the dataset
people_descriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1049024 entries, 0 to 1049023
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   uuid         1049024 non-null  object
#  1   name         1049024 non-null  object
#  2   type         1049024 non-null  object
#  3   permalink    1049016 non-null  object
#  4   cb_url       1049016 non-null  object
#  5   rank         1047902 non-null  float64
#  6   created_at   1049024 non-null  object
#  7   updated_at   1049024 non-null  object
#  8   description  1049011 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 72.0+ MB

# %%
# Read the degrees.csv file and check the top 5 rows
degrees = pd.read_csv('data//degrees.csv')
degrees.head()
# Out:
#                                    uuid  \
# 0  205fdfd1-ecac-aa43-262f-219f11755f67
# 1  1a2ac288-eb99-3318-fde5-1517bc168f51
# 2  b978d338-7ccc-7469-5ce7-ef98c34155ad
# 3  d01cfaad-0ccc-631e-0382-1e507bf6ba04
# 4  16a607f5-8ab3-573e-8d09-57b3e352e1d3
#
#                                                 name    type  permalink  \
# 0         MS  Mass Communication @ Boston University  degree        NaN
# 1  BA  English, French @ Washington University in...  degree        NaN
# 2  MS  Internet Technology @ University of Greenwich  degree        NaN
# 3     BS  Computer Science @ Northeastern University  degree        NaN
# 4  BS  Computer Science @ Rochester Institute of ...  degree        NaN
#
#    cb_url  rank           created_at           updated_at  \
# 0     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:40:03
# 1     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:39:57
# 2     NaN   NaN  2008-02-19 23:40:40  2018-02-13 01:43:09
# 3     NaN   NaN  2008-02-21 01:31:01  2018-02-13 01:43:33
# 4     NaN   NaN  2008-02-21 01:31:34  2018-02-13 01:39:53
#
#                             person_uuid       person_name  \
# 0  4897dba9-3141-ecc0-2c4b-c9d844e6440f        John Green
# 1  4897dba9-3141-ecc0-2c4b-c9d844e6440f        John Green
# 2  29ea5efc-fd7a-402b-3a5d-b8660ac105ea  Sridhar Gundaiah
# 3  45e29113-19f9-c828-68d0-42ad2ef04da0      John Furrier
# 4  b3b4ec6b-86fe-dd6e-ec8a-e8e7e999f274       Ian Reardon
#
#                        institution_uuid                    institution_name  \
# 0  1eab62d2-15d9-0db7-930f-2aa77d4688e1                   Boston University
# 1  6ae9957a-8fb4-0ab1-73fa-dd547c4d3da4  Washington University in St. Louis
# 2  b5ea73f6-12a3-576d-ae9b-f4169147f974             University of Greenwich
# 3  5f84d9fa-78fd-14b0-d335-5ac3561cdc0a             Northeastern University
# 4  1a380593-fb9d-7f7b-ae67-784ce3ff3690   Rochester Institute of Technology
#
#   degree_type              subject started_on completed_on  is_completed
# 0          MS   Mass Communication        NaN   1992-01-01          True
# 1          BA      English, French        NaN   1990-01-01          True
# 2          MS  Internet Technology        NaN   2006-01-01          True
# 3          BS     Computer Science        NaN   1988-01-01          True
# 4          BS     Computer Science        NaN   2002-01-01          True

# %%
# Get the general information on the dataset
degrees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 697290 entries, 0 to 697289
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   uuid              697290 non-null  object
#  1   name              571810 non-null  object
#  2   type              697290 non-null  object
#  3   permalink         0 non-null       float64
#  4   cb_url            0 non-null       float64
#  5   rank              0 non-null       float64
#  6   created_at        697290 non-null  object
#  7   updated_at        697290 non-null  object
#  8   person_uuid       697290 non-null  object
#  9   person_name       697290 non-null  object
#  10  institution_uuid  697290 non-null  object
#  11  institution_name  697290 non-null  object
#  12  degree_type       655203 non-null  object
#  13  subject           585817 non-null  object
#  14  started_on        395661 non-null  object
#  15  completed_on      443185 non-null  object
#  16  is_completed      697290 non-null  bool
# dtypes: bool(1), float64(3), object(13)
# memory usage: 85.8+ MB

# %%
# Read the funding_rounds.csv file and check the top 5 rows
funding_rounds = pd.read_csv('data/funding_rounds.csv')
funding_rounds.head()
# Out:
#                                    uuid                    name  \
# 0  8a945939-18e0-cc9d-27b9-bf33817b2818      Angel Round - Meta
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 2  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 3  bcd5a63d-ed99-6963-0dd2-e36f6582f846  Series B - Photobucket
# 4  60e6afd9-1215-465a-dd17-0ed600d4e29b         Series A - Geni
#
#             type                       permalink  \
# 0  funding_round        facebook-angel--8a945939
# 1  funding_round     facebook-series-a--d950d7a5
# 2  funding_round     facebook-series-b--6fae3958
# 3  funding_round  photobucket-series-b--bcd5a63d
# 4  funding_round         geni-series-a--60e6afd9
#
#                                               cb_url      rank  \
# 0  https://www.crunchbase.com/funding_round/faceb...  122966.0
# 1  https://www.crunchbase.com/funding_round/faceb...  508333.0
# 2  https://www.crunchbase.com/funding_round/faceb...  250596.0
# 3  https://www.crunchbase.com/funding_round/photo...  312853.0
# 4  https://www.crunchbase.com/funding_round/geni-...  452929.0
#
#             created_at           updated_at country_code state_code  ...  \
# 0  2007-05-27 06:08:18  2018-02-12 23:05:39          USA         CA  ...
# 1  2007-05-27 06:09:10  2018-02-12 23:52:16          USA         CA  ...
# 2  2007-05-27 06:09:36  2018-02-12 23:30:46          USA         CA  ...
# 3  2007-05-29 11:05:59  2018-02-12 23:27:36          USA         CO  ...
# 4  2007-05-31 20:19:28  2018-02-12 23:41:29          USA         CA  ...
#
#   raised_amount_usd raised_amount raised_amount_currency_code  \
# 0          500000.0      500000.0                         USD
# 1        12700000.0    12700000.0                         USD
# 2        27500000.0    27500000.0                         USD
# 3        10500000.0    10500000.0                         USD
# 4               NaN           NaN                         NaN
#
#   post_money_valuation_usd  post_money_valuation  \
# 0                      NaN                   NaN
# 1               98000000.0            98000000.0
# 2              502500000.0           502500000.0
# 3                      NaN                   NaN
# 4               10000000.0            10000000.0
#
#    post_money_valuation_currency_code investor_count  \
# 0                                 NaN            4.0
# 1                                 USD            4.0
# 2                                 USD            5.0
# 3                                 NaN            2.0
# 4                                 USD            1.0
#
#                                org_uuid     org_name  \
# 0  df662812-7f97-0b43-9d3e-12f64f504fbb         Meta
# 1  df662812-7f97-0b43-9d3e-12f64f504fbb         Meta
# 2  df662812-7f97-0b43-9d3e-12f64f504fbb         Meta
# 3  f53cb4de-236e-0b1b-dee8-7104a8b018f9  Photobucket
# 4  4111dc8b-c0df-2d24-ed33-30cd137b3098         Geni
#
#                                  lead_investor_uuids
# 0               3f47be49-2e32-8118-01a0-31685a4d0fd7
# 1               b08efc27-da40-505a-6f9d-c9e14247bf36
# 2  e2006571-6b7a-e477-002a-f7014f48a7e3,8d5c7e48-...
# 3                                                NaN
# 4               fb2f8884-ec07-895a-48d7-d9a9d4d7175c
#
# [5 rows x 24 columns]

# %%
# Get the general information on the dataset
funding_rounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535142 entries, 0 to 535141
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   uuid                                535142 non-null  object
#  1   name                                535142 non-null  object
#  2   type                                535142 non-null  object
#  3   permalink                           535129 non-null  object
#  4   cb_url                              535129 non-null  object
#  5   rank                                534952 non-null  float64
#  6   created_at                          535142 non-null  object
#  7   updated_at                          535142 non-null  object
#  8   country_code                        528092 non-null  object
#  9   state_code                          275169 non-null  object
#  10  region                              528092 non-null  object
#  11  city                                528092 non-null  object
#  12  investment_type                     535142 non-null  object
#  13  announced_on                        535142 non-null  object
#  14  raised_amount_usd                   382054 non-null  float64
#  15  raised_amount                       382056 non-null  float64
#  16  raised_amount_currency_code         382056 non-null  object
#  17  post_money_valuation_usd            30498 non-null   float64
#  18  post_money_valuation                30498 non-null   float64
#  19  post_money_valuation_currency_code  30498 non-null   object
#  20  investor_count                      396515 non-null  float64
#  21  org_uuid                            535142 non-null  object
#  22  org_name                            535139 non-null  object
#  23  lead_investor_uuids                 212209 non-null  object
# dtypes: float64(6), object(18)
# memory usage: 98.0+ MB

# %%
# Read the investments.csv file and check the top 5 rows
investments = pd.read_csv('data/investments.csv')
investments.head()
# Out:
#                                    uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d
# 1  6556ab92-6465-25aa-1ffc-7f8b4b09a476
# 2  0216e06a-61f8-9cf1-19ba-20811229c53e
# 3  dadd7d86-520d-5e35-3033-fc1d8792ab91
# 4  581c4b38-9653-7117-9bd4-7ffe5c7eba69
#
#                                                 name        type  \
# 0                Accel investment in Series A - Meta  investment
# 1             Greylock investment in Series B - Meta  investment
# 2  Meritech Capital Partners investment in Series...  investment
# 3  Trinity Ventures investment in Series B - Phot...  investment
# 4        Founders Fund investment in Series A - Geni  investment
#
#                                            permalink  \
# 0  accel-invested-in-facebook-series-a--d950d7a5-...
# 1  greylock-invested-in-facebook-series-b--6fae39...
# 2  meritech-capital-partners-invested-in-facebook...
# 3  trinity-ventures-invested-in-photobucket-serie...
# 4  founders-fund-invested-in-geni-series-a--60e6a...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/investment/accel-in...   NaN
# 1  https://www.crunchbase.com/investment/greylock...   NaN
# 2  https://www.crunchbase.com/investment/meritech...   NaN
# 3  https://www.crunchbase.com/investment/trinity-...   NaN
# 4  https://www.crunchbase.com/investment/founders...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-27 06:09:10  2018-02-13 00:52:57
# 1  2007-05-27 06:09:36  2018-02-13 00:53:20
# 2  2007-05-27 06:09:36  2019-03-27 19:50:32
# 3  2007-05-29 11:05:59  2018-02-13 00:55:58
# 4  2007-05-31 20:19:28  2018-02-13 00:53:04
#
#                      funding_round_uuid      funding_round_name  \
# 0  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 1  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 2  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 3  bcd5a63d-ed99-6963-0dd2-e36f6582f846  Series B - Photobucket
# 4  60e6afd9-1215-465a-dd17-0ed600d4e29b         Series A - Geni
#
#                           investor_uuid              investor_name  \
# 0  b08efc27-da40-505a-6f9d-c9e14247bf36                      Accel
# 1  e2006571-6b7a-e477-002a-f7014f48a7e3                   Greylock
# 2  8d5c7e48-82da-3025-dd46-346a31bab86f  Meritech Capital Partners
# 3  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9           Trinity Ventures
# 4  fb2f8884-ec07-895a-48d7-d9a9d4d7175c              Founders Fund
#
#   investor_type is_lead_investor
# 0  organization             True
# 1  organization             True
# 2  organization             True
# 3  organization              NaN
# 4  organization             True

# %%
# Get the general information on the dataset
investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869103 entries, 0 to 869102
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   uuid                869103 non-null  object
#  1   name                869088 non-null  object
#  2   type                869103 non-null  object
#  3   permalink           869075 non-null  object
#  4   cb_url              869075 non-null  object
#  5   rank                0 non-null       float64
#  6   created_at          869103 non-null  object
#  7   updated_at          869103 non-null  object
#  8   funding_round_uuid  869102 non-null  object
#  9   funding_round_name  869102 non-null  object
#  10  investor_uuid       869089 non-null  object
#  11  investor_name       869084 non-null  object
#  12  investor_type       869089 non-null  object
#  13  is_lead_investor    378600 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 92.8+ MB

# %%
# Read the investment_partners.csv file and check the top 5 rows
investment_partners = pd.read_csv('data/investment_partners.csv')
investment_partners.head()
# Out:
#                                    uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d
# 1  524986f0-3049-54a4-fa72-f60897a5e61d
# 2  6556ab92-6465-25aa-1ffc-7f8b4b09a476
# 3  0216e06a-61f8-9cf1-19ba-20811229c53e
# 4  dadd7d86-520d-5e35-3033-fc1d8792ab91
#
#                                                 name        type  \
# 0                Accel investment in Series A - Meta  investment
# 1                Accel investment in Series A - Meta  investment
# 2             Greylock investment in Series B - Meta  investment
# 3  Meritech Capital Partners investment in Series...  investment
# 4  Trinity Ventures investment in Series B - Phot...  investment
#
#                                            permalink  \
# 0  accel-invested-in-facebook-series-a--d950d7a5-...
# 1  accel-invested-in-facebook-series-a--d950d7a5-...
# 2  greylock-invested-in-facebook-series-b--6fae39...
# 3  meritech-capital-partners-invested-in-facebook...
# 4  trinity-ventures-invested-in-photobucket-serie...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/investment/accel-in...   NaN
# 1  https://www.crunchbase.com/investment/accel-in...   NaN
# 2  https://www.crunchbase.com/investment/greylock...   NaN
# 3  https://www.crunchbase.com/investment/meritech...   NaN
# 4  https://www.crunchbase.com/investment/trinity-...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-27 06:09:10  2018-02-13 00:52:57
# 1  2007-05-27 06:09:10  2018-02-13 00:52:57
# 2  2007-05-27 06:09:36  2018-02-13 00:53:20
# 3  2007-05-27 06:09:36  2019-03-27 19:50:32
# 4  2007-05-29 11:05:59  2018-02-13 00:55:58
#
#                      funding_round_uuid      funding_round_name  \
# 0  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb         Series A - Meta
# 2  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 3  6fae3958-a001-27c0-fb7e-666266aedd78         Series B - Meta
# 4  bcd5a63d-ed99-6963-0dd2-e36f6582f846  Series B - Photobucket
#
#                           investor_uuid              investor_name  \
# 0  b08efc27-da40-505a-6f9d-c9e14247bf36                      Accel
# 1  b08efc27-da40-505a-6f9d-c9e14247bf36                      Accel
# 2  e2006571-6b7a-e477-002a-f7014f48a7e3                   Greylock
# 3  8d5c7e48-82da-3025-dd46-346a31bab86f  Meritech Capital Partners
# 4  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9           Trinity Ventures
#
#                            partner_uuid  partner_name
# 0  2d78d1e7-203c-3eb6-bf1b-c51f10e0679b    Jim Breyer
# 1  eaf6c243-d355-32f3-e23a-2a5fc82e8b34  Kevin Efrusy
# 2  478e7efd-bec4-b9f5-304b-cffedc1fc012     David Sze
# 3  0f9f3c05-cb79-f58f-6cc5-98ddc8382d4f   Paul Madera
# 4  ea9f4980-600c-84f4-a5d6-b4f8c2f787fb       Gus Tai

# %%
# Get the general information on the dataset
investment_partners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188224 entries, 0 to 188223
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   uuid                188224 non-null  object
#  1   name                188224 non-null  object
#  2   type                188224 non-null  object
#  3   permalink           188221 non-null  object
#  4   cb_url              188221 non-null  object
#  5   rank                0 non-null       float64
#  6   created_at          188224 non-null  object
#  7   updated_at          188224 non-null  object
#  8   funding_round_uuid  188224 non-null  object
#  9   funding_round_name  188224 non-null  object
#  10  investor_uuid       188224 non-null  object
#  11  investor_name       188224 non-null  object
#  12  partner_uuid        188224 non-null  object
#  13  partner_name        188224 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 20.1+ MB

# %%
# Read the investors.csv file and check the top 5 rows
investors = pd.read_csv('data/investors.csv')
investors.head()
# Out:
#                                    uuid             name          type  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71      Ben Elowitz        person
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 3  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
# 4  a01b8d46-d311-3333-7c34-aa3ae9c03f22  Mark Zuckerberg        person
#
#          permalink                                             cb_url  \
# 0      ben-elowitz      https://www.crunchbase.com/person/ben-elowitz
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 3         facebook   https://www.crunchbase.com/organization/facebook
# 4  mark-zuckerberg  https://www.crunchbase.com/person/mark-zuckerberg
#
#        rank           created_at           updated_at             roles  \
# 0  568333.0  2007-05-25 14:03:54  2022-06-27 08:59:09          investor
# 1    7001.0  2007-05-26 02:30:28  2022-11-30 00:28:26  investor,company
# 2   50014.0  2007-05-26 03:21:34  2022-07-19 01:45:23  investor,company
# 3      13.0  2007-05-26 04:22:15  2022-08-05 13:19:05  investor,company
# 4  444236.0  2007-05-26 04:51:46  2022-07-28 08:50:59          investor
#
#              domain  ... investment_count total_funding_usd total_funding  \
# 0  wetpaint-inc.com  ...              2.0               NaN           NaN
# 1          zoho.com  ...              9.0               NaN           NaN
# 2       omidyar.com  ...            340.0               NaN           NaN
# 3          meta.com  ...             50.0      2.612282e+10  2.612282e+10
# 4               NaN  ...              8.0               NaN           NaN
#
#   total_funding_currency_code  founded_on  closed_on  \
# 0                         NaN         NaN        NaN
# 1                         NaN  1996-03-17        NaN
# 2                         NaN  2004-01-01        NaN
# 3                         USD  2004-02-04        NaN
# 4                         NaN         NaN        NaN
#
#                              facebook_url  \
# 0         http://www.facebook.com/elowitz
# 1            http://www.facebook.com/zoho
# 2  http://www.facebook.com/OmidyarNetwork
# 3           https://www.facebook.com/Meta
# 4           https://www.facebook.com/zuck
#
#                                         linkedin_url  \
# 0                https://www.linkedin.com/in/elowitz
# 1              https://www.linkedin.com/company/zoho
# 2              http://www.linkedin.com/company/22806
# 3              https://www.linkedin.com/company/meta
# 4  https://www.linkedin.com/in/mark-zuckerberg-61...
#
#                          twitter_url  \
# 0         http://twitter.com/elowitz
# 1            http://twitter.com/zoho
# 2  http://twitter.com/OmidyarNetwork
# 3           https://twitter.com/Meta
# 4          https://twitter.com/finkd
#
#                                             logo_url
# 0  https://res.cloudinary.com/crunchbase-producti...
# 1  https://res.cloudinary.com/crunchbase-producti...
# 2  https://res.cloudinary.com/crunchbase-producti...
# 3  https://res.cloudinary.com/crunchbase-producti...
# 4  https://res.cloudinary.com/crunchbase-producti...
#
# [5 rows x 25 columns]

# %%
# Get the general information on the dataset
investors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241489 entries, 0 to 241488
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   uuid                         241489 non-null  object
#  1   name                         241484 non-null  object
#  2   type                         241489 non-null  object
#  3   permalink                    241487 non-null  object
#  4   cb_url                       241487 non-null  object
#  5   rank                         241009 non-null  float64
#  6   created_at                   241489 non-null  object
#  7   updated_at                   241489 non-null  object
#  8   roles                        241489 non-null  object
#  9   domain                       92410 non-null   object
#  10  country_code                 177665 non-null  object
#  11  state_code                   81168 non-null   object
#  12  region                       168695 non-null  object
#  13  city                         165119 non-null  object
#  14  investor_types               130263 non-null  object
#  15  investment_count             125310 non-null  float64
#  16  total_funding_usd            9360 non-null    float64
#  17  total_funding                9360 non-null    float64
#  18  total_funding_currency_code  9360 non-null    object
#  19  founded_on                   62550 non-null   object
#  20  closed_on                    712 non-null     object
#  21  facebook_url                 40014 non-null   object
#  22  linkedin_url                 145227 non-null  object
#  23  twitter_url                  58633 non-null   object
#  24  logo_url                     177751 non-null  object
# dtypes: float64(4), object(21)
# memory usage: 46.1+ MB

# %%
# Read the funds.csv file and check the top 5 rows
funds = pd.read_csv('data/funds.csv')
funds.head()
# Out:
#                                    uuid                                 name  \
# 0  8190b28a-3c78-0ac4-1e7c-f0b5edce4b2e               DFJ Dragon Second Fund
# 1  cbb6644a-eafb-4686-5505-61f32e1c3638               Sequoia Israel Fund IV
# 2  19fa5c4f-23c3-8c03-2b37-bcd0334505c9                 InterWest Tenth Fund
# 3  e803081d-0974-eda7-ab5f-c0f1a0a432fe              U.S. Venture Partners X
# 4  49a5722a-084c-3466-fd90-37e885c800b1  Inventus Capital Partners Fund I LP
#
#    type                                          permalink  \
# 0  fund  dfj-dragonfund-raised-dfj-dragon-second-fund--...
# 1  fund  sequoia-capital-raised-sequoia-israel-fund-iv-...
# 2  fund  interwest-partners-raised-interwest-tenth-fund...
# 3  fund  us-venture-partners-raised-u-s--venture-partne...
# 4  fund  inventus-capital-partners-raised-inventus-capi...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/fund/dfj-dragonfund...   NaN
# 1  https://www.crunchbase.com/fund/sequoia-capita...   NaN
# 2  https://www.crunchbase.com/fund/interwest-part...   NaN
# 3  https://www.crunchbase.com/fund/us-venture-par...   NaN
# 4  https://www.crunchbase.com/fund/inventus-capit...   NaN
#
#             created_at           updated_at  \
# 0  2008-12-17 03:07:16  2018-02-12 23:51:25
# 1  2008-12-18 22:04:42  2018-02-13 00:38:07
# 2  2008-12-31 09:47:51  2018-02-12 23:51:04
# 3  2009-01-01 18:13:44  2018-02-12 23:46:44
# 4  2009-01-06 18:58:58  2018-02-12 23:35:11
#
#                             entity_uuid                entity_name  \
# 0  fe743289-a4aa-a470-00d8-bbe937e0955b             DFJ DragonFund
# 1  0c867fde-2b9a-df10-fdb9-66b74f355f91            Sequoia Capital
# 2  3eb9d040-1487-8d0e-4db8-72ec93ce32a5         InterWest Partners
# 3  a2b35e8b-e3e9-883b-8a07-38e6ef57d726      U.S. Venture Partners
# 4  c00d6191-2fbe-f796-54b3-fab074445635  Inventus Capital Partners
#
#     entity_type announced_on  raised_amount_usd  raised_amount  \
# 0  organization   2008-12-16        300000000.0    300000000.0
# 1  organization   2008-12-17        200750000.0    200750000.0
# 2  organization   2008-08-11        650000000.0    650000000.0
# 3  organization   2008-07-07        625000000.0    625000000.0
# 4  organization   2007-12-04         51750000.0     51750000.0
#
#   raised_amount_currency_code
# 0                         USD
# 1                         USD
# 2                         USD
# 3                         USD
# 4                         USD

# %%
# Get the general information on the dataset
funds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21956 entries, 0 to 21955
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   uuid                         21956 non-null  object
#  1   name                         21956 non-null  object
#  2   type                         21956 non-null  object
#  3   permalink                    21956 non-null  object
#  4   cb_url                       21956 non-null  object
#  5   rank                         0 non-null      float64
#  6   created_at                   21956 non-null  object
#  7   updated_at                   21956 non-null  object
#  8   entity_uuid                  21956 non-null  object
#  9   entity_name                  21956 non-null  object
#  10  entity_type                  21956 non-null  object
#  11  announced_on                 21098 non-null  object
#  12  raised_amount_usd            18042 non-null  float64
#  13  raised_amount                18097 non-null  float64
#  14  raised_amount_currency_code  18097 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 2.5+ MB

# %%
# Read the category_groups.csv file and check the top 5 rows
acquisitions = pd.read_csv('data//acquisitions.csv')
acquisitions.head()
# Out:
#                                    uuid  \
# 0  c62807f2-3487-f63b-e7fc-559b752ed44c
# 1  419cabe1-4d71-5f64-3e9b-c9d0fb445cca
# 2  01bd2058-ccf8-6102-f253-9224a67a592b
# 3  831becd6-e913-b9f5-ac09-2bff915f9453
# 4  9da90ee7-aad7-e0b4-8456-839363032e5e
#
#                                         name         type  \
# 0  Flektor acquired by Fox Interactive Media  acquisition
# 1            GrandCentral acquired by Google  acquisition
# 2      Last.fm acquired by CBS Entertainment  acquisition
# 3              FeedBurner acquired by Google  acquisition
# 4    Recipezaar acquired by Scripps Networks  acquisition
#
#                                            permalink  \
# 0   fox-interactive-media-acquires-flektor--c62807f2
# 1             google-acquires-grandcentral--419cabe1
# 2                     cbs-acquires-last-fm--01bd2058
# 3               google-acquires-feedburner--831becd6
# 4  scripps-networks-interactive-acquires-recipeza...
#
#                                               cb_url      rank  \
# 0  https://www.crunchbase.com/acquisition/fox-int...  107122.0
# 1  https://www.crunchbase.com/acquisition/google-...   37647.0
# 2  https://www.crunchbase.com/acquisition/cbs-acq...   47919.0
# 3  https://www.crunchbase.com/acquisition/google-...   84744.0
# 4  https://www.crunchbase.com/acquisition/scripps...   59160.0
#
#             created_at           updated_at  \
# 0  2007-05-31 22:19:54  2018-02-13 00:09:05
# 1  2007-07-03 08:14:50  2018-02-12 22:14:26
# 2  2007-07-12 04:19:24  2018-02-12 23:41:20
# 3  2007-07-13 09:52:59  2018-02-12 23:43:38
# 4  2007-07-20 05:29:07  2018-02-12 23:51:07
#
#                           acquiree_uuid acquiree_name  ...  \
# 0  180ebf67-68d0-2316-e93d-8e1e546330ba       Flektor  ...
# 1  5b05e013-a448-3a0b-d872-a6ae668e1192  GrandCentral  ...
# 2  8249dffa-1ca6-6f99-9f76-d56c83f85f2d       Last.fm  ...
# 3  10dd03fa-69ff-3a82-6321-c6b16c9a9f41    FeedBurner  ...
# 4  0af10345-613d-e144-f8bd-b62e288985a0    Recipezaar  ...
#
#                                      acquirer_cb_url acquirer_country_code  \
# 0  https://www.crunchbase.com/organization/fox-in...                   USA
# 1     https://www.crunchbase.com/organization/google                   USA
# 2        https://www.crunchbase.com/organization/cbs                   USA
# 3     https://www.crunchbase.com/organization/google                   USA
# 4  https://www.crunchbase.com/organization/scripp...                   USA
#
#   acquirer_state_code acquirer_region  acquirer_city acquisition_type  \
# 0                  CA      California  Beverly Hills              NaN
# 1                  CA      California  Mountain View              NaN
# 2                  NY        New York       New York              NaN
# 3                  CA      California  Mountain View      acquisition
# 4                  TN       Tennessee      Knoxville              NaN
#
#   acquired_on    price_usd        price price_currency_code
# 0  2007-05-30          NaN          NaN                 NaN
# 1  2007-07-01   60000000.0   60000000.0                 USD
# 2  2007-05-01  280000000.0  280000000.0                 USD
# 3  2007-05-23  100000000.0  100000000.0                 USD
# 4  2007-07-01          NaN          NaN                 NaN
#
# [5 rows x 27 columns]

# %%
# Get the general information on the dataset
acquisitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147431 entries, 0 to 147430
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   uuid                   147431 non-null  object
#  1   name                   147431 non-null  object
#  2   type                   147431 non-null  object
#  3   permalink              147429 non-null  object
#  4   cb_url                 147429 non-null  object
#  5   rank                   147426 non-null  float64
#  6   created_at             147431 non-null  object
#  7   updated_at             147431 non-null  object
#  8   acquiree_uuid          147431 non-null  object
#  9   acquiree_name          147431 non-null  object
#  10  acquiree_cb_url        147431 non-null  object
#  11  acquiree_country_code  139991 non-null  object
#  12  acquiree_state_code    78263 non-null   object
#  13  acquiree_region        139991 non-null  object
#  14  acquiree_city          139991 non-null  object
#  15  acquirer_uuid          147431 non-null  object
#  16  acquirer_name          147431 non-null  object
#  17  acquirer_cb_url        147429 non-null  object
#  18  acquirer_country_code  146789 non-null  object
#  19  acquirer_state_code    86540 non-null   object
#  20  acquirer_region        146789 non-null  object
#  21  acquirer_city          146789 non-null  object
#  22  acquisition_type       136452 non-null  object
#  23  acquired_on            147431 non-null  object
#  24  price_usd              24856 non-null   float64
#  25  price                  24856 non-null   float64
#  26  price_currency_code    24856 non-null   object
# dtypes: float64(3), object(24)
# memory usage: 30.4+ MB

# %%
# Read the ipos.csv file and check the top 5 rows
ipos = pd.read_csv('data/ipos.csv')
ipos.head()
# Out:
#                                    uuid  name type  \
# 0  72d30ebd-53ef-2486-6c29-22785c5173ce   NaN  ipo
# 1  3ad2b068-2d97-f646-0b80-1e5f3d7adfc4   NaN  ipo
# 2  a265c6f6-4b96-4079-096a-967a37f3da2b   NaN  ipo
# 3  ee426509-826e-5dd0-9309-e79c8f384904   NaN  ipo
# 4  66b57372-77f0-ec5f-ca33-0175fff79b0e   NaN  ipo
#
#                                permalink  \
# 0                microsoft-ipo--72d30ebd
# 1  the-walt-disney-company-ipo--3ad2b068
# 2                     divx-ipo--a265c6f6
# 3                 xo-group-ipo--ee426509
# 4             bmc-software-ipo--66b57372
#
#                                               cb_url     rank  \
# 0  https://www.crunchbase.com/ipo/microsoft-ipo--...  10718.0
# 1  https://www.crunchbase.com/ipo/the-walt-disney...  23426.0
# 2  https://www.crunchbase.com/ipo/divx-ipo--a265c6f6  48610.0
# 3  https://www.crunchbase.com/ipo/xo-group-ipo--e...  18551.0
# 4  https://www.crunchbase.com/ipo/bmc-software-ip...  15235.0
#
#             created_at           updated_at  \
# 0  2008-02-09 05:25:18  2018-02-12 23:11:05
# 1  2008-02-09 05:40:32  2019-02-25 22:31:49
# 2  2008-02-25 23:52:11  2018-02-12 23:57:54
# 3  2008-02-29 00:31:34  2018-02-12 23:41:42
# 4  2008-03-18 14:07:10  2020-12-09 11:02:40
#
#                                org_uuid                 org_name  ...  \
# 0  fd80725f-53fc-7009-9878-aeecf1e9ffbb                Microsoft  ...
# 1  756936c0-c335-f0ae-0a3d-fe26bdff5695  The Walt Disney Company  ...
# 2  73296f0d-85a5-78d5-90b3-86c5f8981ba9                     DivX  ...
# 3  ff8439cf-097c-a88a-9bb9-dd83d23aa14b       The Knot Worldwide  ...
# 4  ab8e5ba4-df5d-121b-93b6-eae7a0c89245             BMC Software  ...
#
#   went_public_on share_price_usd share_price share_price_currency_code  \
# 0     1986-03-13             NaN         NaN                       NaN
# 1     1978-01-13             NaN         NaN                       NaN
# 2     2006-10-22            16.0        16.0                       USD
# 3     1999-12-02             NaN         NaN                       NaN
# 4     1988-08-12             NaN         NaN                       NaN
#
#   valuation_price_usd valuation_price valuation_price_currency_code  \
# 0                 NaN             NaN                           NaN
# 1                 NaN             NaN                           NaN
# 2        1.600000e+08    1.600000e+08                           USD
# 3                 NaN             NaN                           NaN
# 4        6.000000e+09    6.000000e+09                           USD
#
#   money_raised_usd  money_raised  money_raised_currency_code
# 0              NaN           NaN                         NaN
# 1      300000000.0   300000000.0                         USD
# 2      145000000.0   145000000.0                         USD
# 3       35000000.0    35000000.0                         USD
# 4              NaN           NaN                         NaN
#
# [5 rows x 27 columns]

# %%
# Get the general information on the dataset
ipos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48638 entries, 0 to 48637
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   uuid                           48638 non-null  object
#  1   name                           0 non-null      float64
#  2   type                           48638 non-null  object
#  3   permalink                      48638 non-null  object
#  4   cb_url                         48638 non-null  object
#  5   rank                           48634 non-null  float64
#  6   created_at                     48638 non-null  object
#  7   updated_at                     48638 non-null  object
#  8   org_uuid                       48638 non-null  object
#  9   org_name                       48638 non-null  object
#  10  org_cb_url                     48638 non-null  object
#  11  country_code                   48544 non-null  object
#  12  state_code                     13664 non-null  object
#  13  region                         48544 non-null  object
#  14  city                           48544 non-null  object
#  15  stock_exchange_symbol          48477 non-null  object
#  16  stock_symbol                   48562 non-null  object
#  17  went_public_on                 48638 non-null  object
#  18  share_price_usd                6021 non-null   float64
#  19  share_price                    6021 non-null   float64
#  20  share_price_currency_code      6021 non-null   object
#  21  valuation_price_usd            3345 non-null   float64
#  22  valuation_price                3345 non-null   float64
#  23  valuation_price_currency_code  3345 non-null   object
#  24  money_raised_usd               6540 non-null   float64
#  25  money_raised                   6540 non-null   float64
#  26  money_raised_currency_code     6540 non-null   object
# dtypes: float64(8), object(19)
# memory usage: 10.0+ MB

# %%
# Read the events.csv file and check the top 5 rows
events = pd.read_csv('data/events.csv')
events.head()
# Out:
#                                    uuid              name   type  \
# 0  6a21f93a-3cae-02ac-44c7-c166c0ed50fa       SF New Tech  event
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2    Adobe MAX 2014  event
# 2  c6006d9f-e796-2a2a-2efc-c4e55caa98f8  ad:tech New York  event
# 3  2710319a-f022-5cd3-f855-6594fd0d6db3   Engadget Expand  event
# 4  35e61ac8-58bf-0492-8285-39dc9c2b236d   Dreamforce 2014  event
#
#                            permalink  \
# 0          sfnt-201272-san-francisco
# 1      adobe-max-2014104-los-angeles
# 2  ad-tech-new-york-2014105-new-york
# 3   engadget-expand-2014107-new-york
# 4  dreamforce-20141013-san-francisco
#
#                                               cb_url     rank  \
# 0  https://www.crunchbase.com/event/sfnt-201272-s...  14384.0
# 1  https://www.crunchbase.com/event/adobe-max-201...  20785.0
# 2  https://www.crunchbase.com/event/ad-tech-new-y...   7534.0
# 3  https://www.crunchbase.com/event/engadget-expa...   8831.0
# 4  https://www.crunchbase.com/event/dreamforce-20...  13580.0
#
#             created_at           updated_at  \
# 0  2014-10-03 18:12:25  2018-02-13 01:14:28
# 1  2014-10-03 18:14:15  2018-02-13 01:14:24
# 2  2014-10-03 18:40:03  2018-02-13 01:14:23
# 3  2014-10-03 18:51:28  2018-02-13 01:14:21
# 4  2014-10-03 19:05:07  2018-06-22 04:56:39
#
#                                    short_description  started_on  ...  \
# 0  Join us on Wed, Oct 15th for another edition o...  2014-10-14  ...
# 1  Sessions, labs, and creativity workshops where...  2014-10-04  ...
# 2  ad:tech New York will showcase keynote speaker...  2014-10-05  ...
# 3  Engadget Expand is designed from the ground up...  2014-11-07  ...
# 4  Dreamforce is your chance to learn from indust...  2014-10-13  ...
#
#                                            event_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://www.montypythonlive.com/best-led-grow-...
#
#                                     registration_url  \
# 0              http://1015sfnt-meetup.eventbrite.com
# 1                 http://max.adobe.com/registration/
# 2                 http://ad-tech.com/ny/registration
# 3  http://www.eventbrite.com/e/engadget-expand-ny...
# 4  http://www.salesforce.com/dreamforce/DF14/regi...
#
#                       venue_name  \
# 0                  RocketStudios
# 1  Los Angeles Convention Center
# 2                  Javits Center
# 3                  Javits Center
# 4                 Moscone Center
#
#                                          description country_code state_code  \
# 0                                                NaN          USA         CA
# 1                                                NaN          USA         CA
# 2                                                NaN          USA         NY
# 3   It’s a free, 10,000+ attendee event that give...          USA         NY
# 4                                                NaN          USA         CA
#
#        region           city  \
# 0  California  San Francisco
# 1  California    Los Angeles
# 2    New York       New York
# 3    New York       New York
# 4  California  San Francisco
#
#                                             logo_url      event_roles
# 0                                                NaN       conference
# 1  https://res.cloudinary.com/crunchbase-producti...       conference
# 2  https://res.cloudinary.com/crunchbase-producti...       conference
# 3  https://res.cloudinary.com/crunchbase-producti...  conference,expo
# 4  https://res.cloudinary.com/crunchbase-producti...       conference
#
# [5 rows x 21 columns]

# %%
# Get the general information on the dataset
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   uuid               27555 non-null  object
#  1   name               27555 non-null  object
#  2   type               27555 non-null  object
#  3   permalink          27555 non-null  object
#  4   cb_url             27555 non-null  object
#  5   rank               26430 non-null  float64
#  6   created_at         27555 non-null  object
#  7   updated_at         27555 non-null  object
#  8   short_description  27555 non-null  object
#  9   started_on         27555 non-null  object
#  10  ended_on           27555 non-null  object
#  11  event_url          21186 non-null  object
#  12  registration_url   27555 non-null  object
#  13  venue_name         20893 non-null  object
#  14  description        20343 non-null  object
#  15  country_code       21435 non-null  object
#  16  state_code         11373 non-null  object
#  17  region             21435 non-null  object
#  18  city               21435 non-null  object
#  19  logo_url           22698 non-null  object
#  20  event_roles        27555 non-null  object
# dtypes: float64(1), object(20)
# memory usage: 4.4+ MB

# %%
# Read the event_appearances.csv and check the top 5 rows
event_appearances = pd.read_csv('data/event_appearances.csv')
event_appearances.head()
# Out:
#                                    uuid  \
# 0  30c4023d-b694-4704-97d7-cd99cd06ecce
# 1  dffe0542-3dac-4228-a997-3eed42cbd67e
# 2  21884e6c-d097-4c54-8513-10536a0ea60d
# 3  c3782f8f-4684-47d6-8649-d0b3e1825eb5
# 4  55e2ee8b-b5b7-49d3-bd21-a63eedf6b7f2
#
#                                          name              type  \
# 0  Adobe MAX 2014's sponsor - CDW Corporation  event_appearance
# 1        Adobe MAX 2014's sponsor - Microsoft  event_appearance
# 2          Adobe MAX 2014's sponsor - Twitter  event_appearance
# 3               Adobe MAX 2014's sponsor - HP  event_appearance
# 4            Adobe MAX 2014's sponsor - Intel  event_appearance
#
#                                            permalink  \
# 0  cdw-corporation-sponsor-adobe-max-2014104-los-...
# 1  microsoft-sponsor-adobe-max-2014104-los-angele...
# 2  twitter-sponsor-adobe-max-2014104-los-angeles-...
# 3  hewlett-packard-sponsor-adobe-max-2014104-los-...
# 4  intel-sponsor-adobe-max-2014104-los-angeles--5...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/event_appearance/cd...   NaN
# 1  https://www.crunchbase.com/event_appearance/mi...   NaN
# 2  https://www.crunchbase.com/event_appearance/tw...   NaN
# 3  https://www.crunchbase.com/event_appearance/he...   NaN
# 4  https://www.crunchbase.com/event_appearance/in...   NaN
#
#             created_at           updated_at  \
# 0  2014-10-03 18:21:26  2018-02-13 01:16:54
# 1  2014-10-03 18:21:42  2018-02-13 01:16:21
# 2  2014-10-03 18:21:55  2018-02-13 01:16:23
# 3  2014-10-03 18:22:03  2018-02-13 01:16:54
# 4  2014-10-03 18:22:11  2018-02-13 01:16:24
#
#                              event_uuid      event_name  \
# 0  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 2  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 3  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 4  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
#
#                        participant_uuid participant_name participant_type  \
# 0  ae883a31-3739-7eb9-4ce0-463ee070ed79  CDW Corporation     organization
# 1  fd80725f-53fc-7009-9878-aeecf1e9ffbb        Microsoft     organization
# 2  5da6106f-0d27-0d37-e9d7-dcfeccc1f709          Twitter     organization
# 3  8adadbfb-be63-6602-8ca0-b037397a7038               HP     organization
# 4  1e4f199c-363b-451b-a164-f94571075ee5            Intel     organization
#
#   appearance_type short_description
# 0         sponsor               NaN
# 1         sponsor               NaN
# 2         sponsor               NaN
# 3         sponsor               NaN
# 4         sponsor               NaN

# %%
# Get the general information on the dataset
event_appearances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434025 entries, 0 to 434024
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uuid               434025 non-null  object
#  1   name               434006 non-null  object
#  2   type               434025 non-null  object
#  3   permalink          434001 non-null  object
#  4   cb_url             434001 non-null  object
#  5   rank               0 non-null       float64
#  6   created_at         434025 non-null  object
#  7   updated_at         434025 non-null  object
#  8   event_uuid         434025 non-null  object
#  9   event_name         434025 non-null  object
#  10  participant_uuid   434006 non-null  object
#  11  participant_name   434005 non-null  object
#  12  participant_type   434006 non-null  object
#  13  appearance_type    434025 non-null  object
#  14  short_description  57354 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 49.7+ MB

# %%
# Read the jobs.csv file and check the top 5 rows
jobs = pd.read_csv('data/jobs.csv')
jobs.head()
# Out:
#                                    uuid  \
# 0  697b6934-fc1f-9d63-cfb2-1a10759b378e
# 1  b1de3765-442e-b556-9304-551c2a055901
# 2  1319cd30-f5e8-c700-0af6-64029c6f7124
# 3  27a252de-1ea8-c620-b2d4-5b889fa9b40f
# 4  5a802a79-229f-44ae-0aba-db330f10b67a
#
#                                         name type  \
# 0  Ben Elowitz Co-Founder and CEO @ Wetpaint  job
# 1     Kevin Flaherty VP Marketing @ Wetpaint  job
# 2       Raju Vegesna Chief Evangelist @ Zoho  job
# 3   Ian Wenig VP Business Development @ Zoho  job
# 4                     Jay Adelson CEO @ Digg  job
#
#                                      permalink  \
# 0     ben-elowitz-executive-wetpaint--697b6934
# 1  kevin-flaherty-executive-wetpaint--b1de3765
# 2         raju-vegesna-employee-zoho--1319cd30
# 3           ian-wenig-executive-zoho--27a252de
# 4         jay-adelson-executive-digg--5a802a79
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/job/ben-elowitz-exe...   NaN
# 1  https://www.crunchbase.com/job/kevin-flaherty-...   NaN
# 2  https://www.crunchbase.com/job/raju-vegesna-em...   NaN
# 3  https://www.crunchbase.com/job/ian-wenig-execu...   NaN
# 4  https://www.crunchbase.com/job/jay-adelson-exe...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-25 07:03:54  2021-03-25 03:59:21
# 1  2007-05-25 07:04:16  2018-02-13 01:32:51
# 2  2007-05-25 19:33:03  2018-02-13 01:19:53
# 3  2007-05-25 19:34:53  2018-02-13 01:21:35
# 4  2007-05-25 20:05:33  2018-02-13 01:25:38
#
#                             person_uuid     person_name  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig
# 4  c92a1f00-8c19-bf2e-0f28-dbbd383dc968     Jay Adelson
#
#                                org_uuid  org_name  started_on    ended_on  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  2005-10-01  2014-06-01
# 1  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint         NaN         NaN
# 2  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  2000-11-01         NaN
# 3  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  2006-03-01         NaN
# 4  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0      Digg  2005-07-01  2010-04-05
#
#    is_current                    title   job_type
# 0       False       Co-Founder and CEO  executive
# 1       False             VP Marketing  executive
# 2        True         Chief Evangelist   employee
# 3        True  VP Business Development  executive
# 4       False                      CEO  executive

# %%
# Get the general information on the dataset
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2566077 entries, 0 to 2566076
# Data columns (total 17 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   uuid         object
#  1   name         object
#  2   type         object
#  3   permalink    object
#  4   cb_url       object
#  5   rank         float64
#  6   created_at   object
#  7   updated_at   object
#  8   person_uuid  object
#  9   person_name  object
#  10  org_uuid     object
#  11  org_name     object
#  12  started_on   object
#  13  ended_on     object
#  14  is_current   bool
#  15  title        object
#  16  job_type     object
# dtypes: bool(1), float64(1), object(15)
# memory usage: 315.7+ MB

# %%
# Read the category_groups.csv file and check the top 5 rows
category_groups = pd.read_csv('data//category_groups.csv')
category_groups.head()
# Out:
#                                    uuid                   name      type  \
# 0  f9b14a15-5517-8f38-0562-729ebb54dfdb       Homeless Shelter  category
# 1  f8320fcf-b657-37d2-1495-daa3ad888ece               Freemium  category
# 2  f0193199-a968-b457-eb49-95344e22a5ce             Industrial  category
# 3  ed8217ff-bd11-26fe-d82e-eb98a276dc2e  Innovation Management  category
# 4  e9794581-9547-2150-8185-7b747f5c9913               Lighting  category
#
#                permalink                                             cb_url  \
# 0       homeless-shelter  https://www.crunchbase.com/category/homeless-s...
# 1               freemium       https://www.crunchbase.com/category/freemium
# 2             industrial     https://www.crunchbase.com/category/industrial
# 3  innovation-management  https://www.crunchbase.com/category/innovation...
# 4               lighting       https://www.crunchbase.com/category/lighting
#
#    rank           created_at           updated_at   category_groups_list
# 0   NaN  2014-04-20 07:58:46  2018-02-13 00:59:11                  Other
# 1   NaN  2014-04-20 07:58:46  2018-02-13 00:59:11                  Other
# 2   NaN  2014-04-20 07:58:46  2018-02-13 00:59:11          Manufacturing
# 3   NaN  2014-04-20 07:58:46  2018-02-13 00:59:11  Professional Services
# 4   NaN  2014-04-20 07:58:46  2018-02-13 00:59:11               Hardware

# %%
# Get the general information on the dataset
category_groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   uuid                  744 non-null    object
#  1   name                  744 non-null    object
#  2   type                  744 non-null    object
#  3   permalink             744 non-null    object
#  4   cb_url                744 non-null    object
#  5   rank                  0 non-null      float64
#  6   created_at            744 non-null    object
#  7   updated_at            744 non-null    object
#  8   category_groups_list  744 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 52.4+ KB

# %%
# Read the org_parents.csv file and check the top 5 rows
org_parents = pd.read_csv('data/org_parents.csv')
org_parents.head()
# Out:
#                                    uuid                   name          type  \
# 0  d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media  organization
# 1  3d9e4070-1a25-7491-d1a9-17bec9f6361b      Hutchison Whampoa  organization
# 2  f09c1228-2e7d-1889-6647-ba5021b2e4ea      CBS Entertainment  organization
# 3  91f5ca18-e026-9482-8e4f-22593943e0f5                  Plaxo  organization
# 4  fc89cfde-a28e-e12c-443c-edccb6c93fd4                AddThis  organization
#
#                    permalink  \
# 0      fox-interactive-media
# 1  hutchison-whampoa-limited
# 2                        cbs
# 3                      plaxo
# 4                    addthis
#
#                                               cb_url    rank  \
# 0  https://www.crunchbase.com/organization/fox-in...  182047
# 1  https://www.crunchbase.com/organization/hutchi...  237393
# 2        https://www.crunchbase.com/organization/cbs  166065
# 3      https://www.crunchbase.com/organization/plaxo  121730
# 4    https://www.crunchbase.com/organization/addthis  159837
#
#             created_at           updated_at  \
# 0  2007-06-01 04:46:57  2022-07-19 01:26:51
# 1  2007-06-09 14:20:16  2023-01-05 11:29:37
# 2  2007-06-09 14:30:10  2022-10-10 04:29:11
# 3  2007-06-09 21:18:54  2020-02-03 09:07:25
# 4  2007-06-13 16:00:07  2019-06-24 21:45:36
#
#                             parent_uuid           parent_name
# 0  ddfe6b91-4541-7f5c-7d6a-724f75c98088      21st Century Fox
# 1  5858c937-702e-c278-1725-2b5e02471482  Cheung Kong Holdings
# 2  cd19ea0d-745c-e3b6-d819-30b91caf8ebb       CBS Corporation
# 3  fbc7746d-86e0-8fd6-19d8-69280c686d02               Comcast
# 4  bef5bd4b-72c6-7877-d7ab-8bbe43f7bda7                Oracle

# %%
# Get the general information on the dataset
org_parents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23931 entries, 0 to 23930
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   uuid         23931 non-null  object
#  1   name         23931 non-null  object
#  2   type         23931 non-null  object
#  3   permalink    23931 non-null  object
#  4   cb_url       23931 non-null  object
#  5   rank         23931 non-null  int64
#  6   created_at   23931 non-null  object
#  7   updated_at   23931 non-null  object
#  8   parent_uuid  23931 non-null  object
#  9   parent_name  23931 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Clean each dataset seperately

# %% [markdown]
# **organizations Dataset**

# %%
# Load and peep at the dataset info again
organizations=pd.read_csv('data/organizations.csv')
organizations.head()

# %%
organizations.info()

# %%
# List the columns for ease of identifying the ones to drop
organizations.columns

# %%
# Remove the unneeded columns
organizations.drop(['permalink', 'cb_url', 'created_at',
       'updated_at', 'num_funding_rounds', 'total_funding_usd',
       'total_funding', 'total_funding_currency_code',
       'last_funding_on', 'logo_url', 'alias1',
       'alias2', 'alias3', 'num_exits'],axis=1,inplace=True )

# %%
# Check for missing values
organizations.isna().sum()

# %%
# Convert the started_on and completed_on to DateTime data type
organizations['founded_on']=pd.to_datetime(organizations['founded_on'],errors = 'coerce')
organizations['closed_on']=pd.to_datetime(organizations['closed_on'],errors = 'coerce')

# %% [markdown]
# If the data type is string this should be replaced with 'not known' and if it is numerical or date it should be replaced with 0

# %%
# Fill the rows with no degree_type, no subject, no started_on, no completed_on.
for col in organizations.columns:
    if organizations[col].dtype == 'O':
        organizations[col].fillna('not known',inplace=True)
    else:
        organizations[col].fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
organizations.isna().sum()

# %%
organizations.info()

# %% [markdown]
# >Please note that the `fillna()` function converts the datatype to `object` so a final imputation to be done on the DateTime variables for using for training our model.
# >The missing dates will be assumed or calculated from other information available in other tables about the organisation such as promoters graduation date, funds raised date etc.

# %%
# Save the clean version of the dataset
organizations.to_csv('Crunchbase Data//clean//organizations_c.csv',index=False)

# %% [markdown]
# **Organisation Description Dataset**

# %%
# Load and peep at the dataset info again
organization_descriptions=pd.read_csv('data//organization_descriptions.csv')
organization_descriptions.head()

# %%
organization_descriptions.info()

# %%
# List the columns for ease of identifying the ones to drop
organization_descriptions.columns

# %%
# Remove the unneeded columns
organization_descriptions.drop([ 'type', 'permalink', 'cb_url', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
organization_descriptions.isna().sum()

# %% [markdown]
# * We will drop the organisations without names
# * Rank the organisations with missing ranks at the tail end of the dataset
# * Organisations without description should be imputed with 'no description'

# %%
# Drop the organisations without names
organization_descriptions['name'].dropna(inplace=True)

# %%
# Missing rank will be imputed with nominal ranks at the tail end of the dataset 
leng= len(organization_descriptions)
counter = pd.Series(range (1,len(organization_descriptions['rank'][organization_descriptions['rank'].isna()] )+1))
organization_descriptions['rank'].mask(organization_descriptions['rank'].isna(), [leng-counter], inplace=True)

# %%
# Organisations without descriptions should be imputed with 'no description'
organization_descriptions['description'].fillna('no description',inplace=True)

# %%
# Confirm that all missing values has been handled
organization_descriptions.isna().sum()

# %%
# Save the clean version of the dataset
organization_descriptions.to_csv('data//clean//organization_descriptions_c.csv',index=False)

# %% [markdown]
# **People Dataset**

# %%
# Load and peep at the dataset info again
people=pd.read_csv('data//people.csv')
people.head()

# %%
people.info()

# %%
# List the columns for ease of identifying the ones to drop
people.columns

# %%
# Remove the unneeded columns
people.drop(['type', 'permalink', 'created_at','updated_at','cb_url','logo_url'],axis=1,inplace=True)

# %%
# Check the missing values
people.isna().sum()

# %% [markdown]
# * The missing rank will be imputed with the nominal value from the tail end of the dataset
# * All other missing values will be imputed with "not known"

# %%
# The missing rank will be imputed with the nominal value from the tail end of the dataset
leng= len(people)
counter = pd.Series(range (1,len(people['rank'][people['rank'].isna()] )+1))
people['rank'].mask(people['rank'].isna(), [leng-counter], inplace=True)

# %%
# All other missing values will be imputed with "not known"
people.fillna('not known',inplace=True)

# %%
# Confirm that all missing values has been handled
people.isna().sum()

# %%
# Save the clean version of the dataset
people.to_csv('data//clean//people_c.csv',index=False)

# %% [markdown]
# **People Description Dataset**

# %%
# Load and peep at the dataset info again
people_descriptions=pd.read_csv('data//people_descriptions.csv')
people_descriptions.head()

# %%
people_descriptions.info()

# %%
# List the columns for ease of identifying the ones to drop
people_descriptions.columns

# %%
# Remove the unneeded columns
people_descriptions.drop([ 'type', 'permalink', 'cb_url','created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
people_descriptions.isna().sum()

# %% [markdown]
# * The missing rank will be imputed with the nominal value from the tail end of the dataset
# * Missing descriptions will be imputed with "no description"

# %%
# The missing rank will be imputed with the nominal value from the tail end of the dataset
# Create helper function to imput rank based on rule above
def imput_rank(df):
    leng= len(df)
    counter = pd.Series(range (1,len(df['rank'][df['rank'].isna()] )+1))
    df['rank'].mask(df['rank'].isna(), [leng-counter], inplace=True)
    
imput_rank(people_descriptions)

# %%
# Missing descriptions will be imputed with "no description"
people_descriptions['description'].fillna('no description',inplace=True)

# %%
# Confirm that all missing values has been handled
people_descriptions.isna().sum()

# %%
# Save the clean version of the dataset
people_descriptions.to_csv('data//clean//people_descriptions_c.csv',index=False)

# %% [markdown]
# **Degrees Dataset**

# %%
# Load and peep at the dataset info again
degrees=pd.read_csv('data/degrees.csv')
degrees.head()

# %%
degrees.info()

# %%
# List the columns for ease of identifying the ones to drop
degrees.columns

# %%
# Remove the unneeded columns
degrees.drop(['name','rank','permalink','cb_url','created_at','updated_at'],axis=1,inplace=True )

# %%
# Check the missing values
degrees.isna().sum()

# %% [markdown]
# * We can assume all the degrees are 4 years, so we can fill degrees with missing start dates with 4 years less than the completion dates when available
# * All other objects will be filled with "not known" and dates with 0

# %%
# Convert the started_on and completed_on to DateTime data type
degrees['completed_on']=pd.to_datetime(degrees['completed_on'],errors = 'coerce')
degrees['started_on']=pd.to_datetime(degrees['started_on'],errors = 'coerce')

# %%
# Fill the started_on date with 4 years less than completed_on date
degrees.loc[degrees['started_on'].isna() & degrees['completed_on'].notna() ,'started_on']=degrees['completed_on']- pd.offsets.DateOffset(years=4)

# %% [markdown]
# We will fill the remaining missing values in `degree_type`,`subject`, `started_on` and `completed_on` with 'not known', 'not known' ,0 and 0 respectively.

# %%
# Fill the rows with no degree_type, no subject, no started_on, no completed_on.
degrees.loc[degrees['degree_type'].isna() | degrees['subject'].isna() | degrees['started_on'].isna() | degrees['completed_on'].isna(),['subject','degree_type','started_on','completed_on']]=['not known','not known',0,0]

# %%
# Confirm that all missing values has been handled
degrees.isna().sum()

# %%
# Save the clean version of the dataset
degrees.to_csv('data//clean//degrees_c.csv',index=False)

# %% [markdown]
# **Funding Rounds Dataset**

# %%
# Load and peep at the dataset info again
funding_rounds=pd.read_csv('data//funding_rounds.csv')
funding_rounds.head()

# %%
funding_rounds.info()

# %%
# List the columns for ease of identifying the ones to drop
funding_rounds.columns

# %%
# Remove the unneeded columns
funding_rounds.drop([ 'type', 'permalink', 'cb_url', 'created_at',
       'updated_at','post_money_valuation_usd','post_money_valuation', 'post_money_valuation_currency_code',
                     'investor_count'],axis=1,inplace=True)

# %%
# Check the missing values
funding_rounds.isna().sum()

# %% [markdown]
# * The missing rank will be imputed with the nominal value from the tail end of the dataset
# * Missing address columns and other objects will be imputed with "not known"
# * Missing numerical values will be imputed with 0

# %%
# The missing rank will be imputed with the nominal value from the tail end of the dataset
imput_rank(funding_rounds)

# %%
# Missing address columns will be imputed with "not known" and numerical values will be imputed with 0
for col in funding_rounds.columns:
    if funding_rounds[col].dtype == 'O':
        funding_rounds[col].fillna('not known',inplace=True)
    else:
        funding_rounds[col].fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
funding_rounds.isna().sum()

# %%
# Save the clean version of the dataset
funding_rounds.to_csv('data//clean//funding_rounds_c.csv',index=False)

# %% [markdown]
# **Investment Dataset**

# %%
# Load and peep at the dataset info again
investments=pd.read_csv('data//investments.csv')
investments.head()

# %%
investments.info()

# %%
# List the columns for ease of identifying the ones to drop
investments.columns

# %%
# Remove the unneeded columns
investments.drop([ 'type', 'permalink', 'cb_url', 'rank', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
investments.isna().sum()

# %% [markdown]
# * Drop the investments rows without the names
# * Drop the rows with missing funding round uuid and name
# * fill all other missing values with "not known"

# %%
# Drop the investments rows without the names, missing funding round uuid and name
investments.dropna(subset=['name','funding_round_uuid','funding_round_name'],inplace=True)

# %%
#  Fill all other missing values with "not known"
investments.fillna('not known',inplace=True)

# %%
# Confirm that all missing values has been handled
investments.isna().sum()

# %%
# Save the clean version of the dataset
investments.to_csv('data//clean//investments_c.csv',index=False)

# %% [markdown]
# **Investment Partner Dataset**

# %%
# Load and peep at the dataset info again
investment_partners=pd.read_csv('data//investment_partners.csv')
investment_partners.head()

# %%
investment_partners.info()

# %%
# List the columns for ease of identifying the ones to drop
investment_partners.columns

# %%
# Remove the unneeded columns
investment_partners.drop(['type', 'permalink','cb_url', 'rank', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
investment_partners.isna().sum()

# %%
# Save the clean version of the dataset
investment_partners.to_csv('data//clean//investment_partners_c.csv',index=False)

# %% [markdown]
# **Investors Dataset**

# %%
# Load and peep at the dataset info again
investors=pd.read_csv('data//investors.csv')
investors.head()

# %%
investors.info()

# %%
# List the columns for ease of identifying the ones to drop
investors.columns

# %%
# Remove the unneeded columns
investors.drop(['permalink', 'cb_url', 'created_at','updated_at','logo_url'],axis=1,inplace=True)

# %%
# Check the missing values
investors.isna().sum()

# %% [markdown]
# * The rows with missing names will be dropped
# * The missing rank will be imputed with the nominal value from the tail end of the dataset
# * Dates will be temporary casted as DateTime (returns object with fillna) so as to fill with 0
# * Other missing values numeric value will be filled with 0
# * Other string values will be filled with "not known"

# %%
# The rows with missing names will be dropped
investors.dropna(subset=['name'],inplace=True)

# %%
# The missing rank will be imputed with the nominal value from the tail end of the dataset
imput_rank(investors)

# %%
# Dates will be temporary casted as DateTime (returns object with fillna) so as to fill with 0
investors['founded_on']=pd.to_datetime(investors['founded_on'],errors = 'coerce')
investors['closed_on']=pd.to_datetime(investors['closed_on'],errors = 'coerce')

# %%
# Fill missing values numeric value and dates will be filled with 0 and other string values will be filled with "not known"
for col in investors.columns:
    if investors[col].dtype == 'O':
        investors[col].fillna('not known',inplace=True)
    else:
        investors[col].fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
investors.isna().sum()

# %%
# Save the clean version of the dataset
investors.to_csv('data//clean//investors_c.csv',index=False)

# %% [markdown]
# **Funds Dataset**

# %%
# Load and peep at the dataset info again
funds=pd.read_csv('data//funds.csv')
funds.head()

# %%
funds.info()

# %%
# List the columns for ease of identifying the ones to drop
funds.columns

# %%
# Remove the unneeded columns
funds.drop([ 'type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
funds.isna().sum()

# %% [markdown]
# * The missing values rows can be dropped as this are not valuable with the amount of the funds

# %%
# Drop all rows with missing values
funds.dropna(subset=['announced_on','raised_amount_usd','raised_amount','raised_amount_currency_code'],inplace=True)

# %%
# Confirm that all missing values has been handled
funds.isna().sum()

# %%
# Save the clean version of the dataset
funds.to_csv('data//clean//funds_c.csv',index=False)

# %% [markdown]
# **Acquisitions Dataset**

# %%
# Load and peep at the dataset info again
acquisitions=pd.read_csv('data//acquisitions.csv')
acquisitions.head()

# %%
acquisitions.info()

# %%
# List the columns for ease of identifying the ones to drop
acquisitions.columns

# %%
# Remove the unneeded columns
acquisitions.drop([ 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at', 'acquiree_cb_url','acquirer_cb_url'],axis=1,inplace=True)

# %%
# Check the missing values
acquisitions.isna().sum()

# %% [markdown]
# * The missing string values (addresses etc) filled with "not known
# * Major information will be to know if a company was acquired thus missing price can be filled with 0
# * Missing price currency code to be filled with USD

# %%
# Missing price currency code to be filled with USD
acquisitions['price_currency_code'].fillna('USD',inplace=True)

# %%
# Missing string values (addresses etc) filled with "not known and numeric values with 0
for col in acquisitions.columns:
    if acquisitions[col].dtype == 'O':
        acquisitions[col].fillna('not known',inplace=True)
    else:
        acquisitions[col].fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
acquisitions.isna().sum()

# %%
# Save the clean version of the dataset
acquisitions.to_csv('data//clean//acquisitions_c.csv',index=False)

# %% [markdown]
# **IPOs Dataset**

# %%
# Load and peep at the dataset info again
ipos=pd.read_csv('data//ipos.csv')
ipos.head()

# %%
ipos.info()

# %%
# List the columns for ease of identifying the ones to drop
ipos.columns

# %%
# Remove the unneeded columns
ipos.drop(['name','type', 'permalink', 'cb_url', 'rank', 'created_at','updated_at', 'org_cb_url'],axis=1,inplace=True)

# %%
# Check the missing values
ipos.isna().sum()

# %% [markdown]
# * The missing string values (addresses etc) filled with "not known
# * Major information will be to know if a company went public via IPO thus missing prices can be filled with 0
# * Missing currency codes to be filled with USD

# %%
# Missing price currency code to be filled with USD
ipos['money_raised_currency_code'].fillna('USD',inplace=True)
ipos['valuation_price_currency_code'].fillna('USD',inplace=True)
ipos['share_price_currency_code'].fillna('USD',inplace=True)

# %%
# Missing string values (addresses etc) filled with "not known and numeric values with 0
for col in ipos.columns:
    if ipos[col].dtype == 'O':
        ipos[col].fillna('not known',inplace=True)
    else:
        ipos[col].fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
ipos.isna().sum()

# %%
# Save the clean version of the dataset
ipos.to_csv('data//clean//ipos_c.csv',index=False)

# %% [markdown]
# **Events Dataset**

# %%
# Load and peep at the dataset info again
events=pd.read_csv('data//events.csv')
events.head()

# %%
events.info()

# %%
# List the columns for ease of identifying the ones to drop
events.columns

# %%
# Remove the unneeded columns
events.drop(['type', 'permalink', 'cb_url', 'created_at','updated_at', 'logo_url'],axis=1,inplace=True)

# %%
# Check the missing values
events.isna().sum()

# %% [markdown]
# * The missing rank will be imputed with the nominal value from the tail end of the dataset
# * Other missing values will be imputed with "not known"

# %%
# missing rank will be imputed with the nominal value from the tail end of the dataset
imput_rank(events)

# %%
# Other missing values will be imputed with "not known"
events.fillna('not known',inplace=True)

# %%
# Confirm that all missing values has been handled
events.isna().sum()

# %%
# Save the clean version of the dataset
events.to_csv('data//clean//events_c.csv',index=False)

# %% [markdown]
# **Events Appearance Dataset**

# %%
# Load and peep at the dataset info again
event_appearances=pd.read_csv('data//event_appearances.csv')
event_appearances.head()

# %%
event_appearances.info()

# %%
# List the columns for ease of identifying the ones to drop
event_appearances.columns

# %%
# Remove the unneeded columns
event_appearances.drop([ 'type', 'permalink', 'cb_url', 'rank', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
event_appearances.isna().sum()

# %% [markdown]
# * The information is only valuable with the name of the participant. All missing values will be dropped

# %%
# Drop rows with missing values
event_appearances.dropna(inplace=True)

# %%
# Confirm that all missing values has been handled
event_appearances.isna().sum()

# %%
# Save the clean version of the dataset
event_appearances.to_csv('data//clean//event_appearances_c.csv',index=False)

# %% [markdown]
# **Jobs Dataset**

# %%
# Load and peep at the dataset info again
jobs=pd.read_csv('data//jobs.csv')
jobs.head()

# %%
jobs.info()

# %%
# List the columns for ease of identifying the ones to drop
jobs.columns

# %%
# Remove the unneeded columns
jobs.drop(['type', 'permalink', 'cb_url', 'rank', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
jobs.isna().sum()

# %% [markdown]
# * The rows with missing personnel names will be dropped
# * The rows with missing organisation names will be dropped
# * Missing job title will be filled with "not known"
# * Missing dates will be filled with 0

# %%
# Rows with missing personnel names, uuid and org_name will be dropped
jobs.dropna(subset=['name','person_uuid','person_name','org_name'],inplace=True)

# %%
# Rows with missing job titles will be filled with "not known"
jobs['title'].fillna('not known',inplace=True)

# %%
# Missing dates will be filled with 0 (will be processed to DateTime before training of model)
jobs.fillna(0,inplace=True)

# %%
# Confirm that all missing values has been handled
jobs.isna().sum()

# %%
# Save the clean version of the dataset
jobs.to_csv('data//clean//jobs_c.csv',index=False)

# %% [markdown]
# **Category_groups Dataset**

# %%
# Load and peep at the dataset info again
category_groups=pd.read_csv('data/category_groups.csv')
category_groups.head()

# %%
category_groups.info()

# %%
# List the columns for ease of identifying the ones to drop
category_groups.columns

# %%
# Remove the unneeded columns
category_groups.drop(['rank','permalink','cb_url','created_at','updated_at'],axis=1,inplace=True)

# %%
category_groups.isna().sum()

# %%
# Save the clean version of the dataset
category_groups.to_csv('data//clean//category_groups_c.csv',index=False)

# %% [markdown]
# **Organization Parent Dataset**

# %%
# Load and peep at the dataset info again
org_parents=pd.read_csv('data//org_parents.csv')
org_parents.head()

# %%
org_parents.info()

# %%
# List the columns for ease of identifying the ones to drop
org_parents.columns

# %%
# Remove the unneeded columns
org_parents.drop([ 'permalink', 'cb_url', 'created_at','updated_at'],axis=1,inplace=True)

# %%
# Check the missing values
org_parents.isna().sum()

# %%
# Save the clean version of the dataset
org_parents.to_csv('data//clean//org_parents_c.csv',index=False)

# %% [markdown]
# ### Merging of Tables to Create Backbone Dataset

# %% [markdown]
# In conformance with the data model created for the project, the applicable tables will be merged to pull in the relevant features or datapoints that will be utilised for the model.
#
# This merged dataset is named the backbone dataset as there will be enrichment of the dataset from the webscraping of the social media handles of the companies and possibly the social media handles of the promoter from at most 5 years from date of founding or 10000 posts on each platform (whichever comes first).
#
# A sentiment analysis will be done on these post and the averages of the polarity and subjectivity will be added as features to the backbone dataset.
#
# From the work of (Żbikowski KAntosiuk P et al, 2021) ,which is also based on crunchbase data, their recommendation for further research was to include the people description and organisation description with are in text as part of the dataset and also find ways to enrich the dataset. These recommendations would be carried out in this work to improve on the previuos related research.
#
# To further remove the bias in using information that would not have been available at the point of investment evaluation e.g IPO, seed funding etc. these data would not be used for training the model but only to set the target variable of whether the company was successful or not. Multiple conditions would be recognised as an indicator of success of the company such as being acquired, IPO, raising series B and above funding sponsorship of industry events etc.

# %%
# import the clean version of datasets that would provide features for the backbone dataset (organizaations)
organizations = pd.read_csv('data//clean//organizations_c.csv',parse_dates=['founded_on','closed_on'])
organizations.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
#
#        rank                  legal_name             roles        domain  \
# 0  194947.0                   not known           company  wetpaint.com
# 1    6999.0  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
# 2   26624.0          Digg Holdings, LLC           company      digg.com
# 3   49970.0                   not known  investor,company   omidyar.com
# 4      13.0        Meta Platforms, Inc.  investor,company      meta.com
#
#                homepage_url country_code state_code  ...  \
# 0  http://www.wetpaint.com/          USA         NY  ...
# 1      https://www.zoho.com          USA         CA  ...
# 2       http://www.digg.com          USA         NY  ...
# 3    http://www.omidyar.com          USA         CA  ...
# 4          https://meta.com          USA         CA  ...
#
#                                 category_groups_list           founded_on  \
# 0  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 1  Administrative Services,Apps,Information Techn...  1996-03-17 00:00:00
# 2          Internet Services,Media and Entertainment  2004-10-11 00:00:00
# 3  Financial Services,Lending and Investments,Sof...  2004-01-01 00:00:00
# 4  Hardware,Internet Services,Media and Entertain...  2004-02-04 00:00:00
#
#   closed_on employee_count               email           phone  \
# 0         0         51-100   info@wetpaint.com    206-859-6300
# 1         0         10000+  sales@zohocorp.com  044 - 67447070
# 2         0         51-100   feedback@digg.com    877-342-7222
# 3         0        101-250    info@omidyar.com    650.482.2500
# 4         0         10000+           not known       not known
#
#                              facebook_url  \
# 0       https://www.facebook.com/Wetpaint
# 1            http://www.facebook.com/zoho
# 2            http://www.facebook.com/digg
# 3  http://www.facebook.com/OmidyarNetwork
# 4           https://www.facebook.com/Meta
#
#                             linkedin_url                        twitter_url  \
# 0                              not known     https://twitter.com/wetpainttv
# 1  https://www.linkedin.com/company/zoho            http://twitter.com/zoho
# 2   http://www.linkedin.com/company/digg            http://twitter.com/digg
# 3  http://www.linkedin.com/company/22806  http://twitter.com/OmidyarNetwork
# 4  https://www.linkedin.com/company/meta           https://twitter.com/Meta
#
#   primary_role
# 0      company
# 1      company
# 2      company
# 3     investor
# 4      company
#
# [5 rows x 27 columns]

# %%
# import the clean version of datasets that would provide features for the backbone dataset (organizaation_descriptions)
organization_descriptions = pd.read_csv('data//clean//organization_descriptions_c.csv')
organization_descriptions.head()
# Out:
#                                    uuid             name      rank  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  194947.0
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho    6999.0
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg   26624.0
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network   49970.0
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta      13.0
#
#                                          description
# 0  Wetpaint is a technology platform company that...
# 1  Zoho offers a suite of business, collaboration...
# 2  Digg Inc. operates a website that enables its ...
# 3  Pierre Omidyar, the founder of eBay, and his w...
# 4  Meta is a social technology company that enabl...

# %%
# Merge with the organization_description table to add the description of the organisation
backbone_ds = pd.merge(organizations, organization_descriptions, on = 'uuid', how = 'left')

# %%
# import the clean version of datasets that would provide features for the backbone dataset (people)
people = pd.read_csv('data//clean//people_c.csv')
people.head()
# Out:
#                                    uuid            name      rank  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz   30872.0
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  731097.0
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna   11465.0
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig  472935.0
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne  638331.0
#
#             created_at           updated_at first_name last_name gender  \
# 0  2007-05-25 14:03:54  2022-06-27 08:59:09        Ben   Elowitz   male
# 1  2007-05-25 14:04:16  2018-02-12 23:14:37      Kevin  Flaherty   male
# 2  2007-05-26 02:33:03  2022-02-24 12:24:29       Raju   Vegesna   male
# 3  2007-05-26 02:34:53  2021-03-23 10:25:04        Ian     Wenig   male
# 4  2007-05-26 03:06:45  2022-04-08 19:52:41       Owen     Byrne   male
#
#   country_code state_code      region           city  \
# 0          USA         WA  Washington        Seattle
# 1          USA         WA  Washington  Mercer Island
# 2          USA         CA  California  San Francisco
# 3    not known  not known   not known      not known
# 4          USA         CA  California  Mountain View
#
#          featured_job_organization_uuid featured_job_organization_name  \
# 0  1d845b32-7d80-47af-957d-78ccbeeaefb6                      Zeitworks
# 1  789e5e4d-0c90-d06e-92a0-b800b461c3da                       DRSmedia
# 2  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
# 3  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
# 4                             not known                      not known
#
#         featured_job_title                     facebook_url  \
# 0               Co-Founder  http://www.facebook.com/elowitz
# 1              Team Member                        not known
# 2         Chief Evangelist                        not known
# 3  VP Business Development                        not known
# 4                not known                        not known
#
#                                        linkedin_url  \
# 0               https://www.linkedin.com/in/elowitz
# 1          http://www.linkedin.com/in/kevinflaherty
# 2  https://www.linkedin.com/in/raju-vegesna-78a6541
# 3                                         not known
# 4               https://www.linkedin.com/in/ojbyrne
#
#                     twitter_url
# 0    http://twitter.com/elowitz
# 1    https://twitter.com/tallkp
# 2     https://twitter.com/rajuv
# 3                     not known
# 4  http://twitter.com/owenbyrne

# %%
# Add the people to the backbone dataset
backbone_ds = pd.merge(backbone_ds, people, right_on='featured_job_organization_uuid',left_on='uuid', how = 'left')

# %%
# import the clean version of datasets that would provide features for the backbone dataset (people_description)
people_descriptions = pd.read_csv('data//clean//people_descriptions_c.csv')
people_descriptions.head()
# Out:
#                                    uuid            name      rank  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz   30872.0
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty  731097.0
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna   11465.0
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig  472935.0
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne  638331.0
#
#                                          description
# 0  Ben Elowitz is a Member Board Of Directors at ...
# 1  Brand development, creative agency management,...
# 2  Raju is an evangelist for Zoho and is one of t...
# 3  Ian Wenig has more then twenty years experienc...
# 4  Legend has it that Owen Byrne was hired by [Di...

# %%
backbone_ds.head(2)
# Out:
#                                  uuid_x    name_x          type    rank_x  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization    6999.0
#
#                    legal_name             roles        domain  \
# 0                   not known           company  wetpaint.com
# 1  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
#
#                homepage_url country_code_x state_code_x  ... country_code_y  \
# 0  http://www.wetpaint.com/            USA           NY  ...            NaN
# 1      https://www.zoho.com            USA           CA  ...            USA
#
#   state_code_y    region_y         city_y  \
# 0          NaN         NaN            NaN
# 1           CA  California  San Francisco
#
#          featured_job_organization_uuid featured_job_organization_name  \
# 0                                   NaN                            NaN
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
#
#   featured_job_title facebook_url_y  \
# 0                NaN            NaN
# 1   Chief Evangelist      not known
#
#                                      linkedin_url_y              twitter_url_y
# 0                                               NaN                        NaN
# 1  https://www.linkedin.com/in/raju-vegesna-78a6541  https://twitter.com/rajuv
#
# [2 rows x 48 columns]

# %% [markdown]
# There is need to clean up the column names before doing further merging of tables and after subsequent merges as well

# %%
# Rename the columns accordingly
backbone_ds.rename(columns={'uuid_x':'uuid_o','name_x':'name_o','rank_x':'rank_o','country_code_x':'country_code_o',
                            'state_code_x':'state_code_o','region_x':'region_o','city_x':'city_o','facebook_url_x':'facebook_url_o',
                             'linkedin_url_x':'linkedin_url_o','twitter_url_x':'twitter_url_o','name_y':'name_o','rank_y':'rank_o',
                             'description':'description_o','uuid_y':'uuid_p','country_code_y':'country_code_p','state_code_y':'state_code_p',
                             'city_y':'city_p','region_y':'region_o','facebook_url_y':'facebook_url_p','linkedin_url_y':'linkedin_url_p','twitter_url_y':'twitter_url_p',
                            'name':'name_p','rank':'rank_p','roles':'roles_o','address':'address_o','short_description':'short_description_o',
                            'email':'email_o','phone':'phone_o','name':'name_p','rank':'rank_p','region_y':'region_p','postal_code':'postal_code_p',
                            'description':'description_o'
                             },inplace=True)

# %%
# Confirm the renamed columns
pd.set_option('display.max_columns',len(backbone_ds.columns))
backbone_ds.head(2)
# Out:
#                                  uuid_o    name_o          type    rank_o  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization    6999.0
#
#                    legal_name           roles_o        domain  \
# 0                   not known           company  wetpaint.com
# 1  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
#
#                homepage_url country_code_o state_code_o    region_o  \
# 0  http://www.wetpaint.com/            USA           NY    New York
# 1      https://www.zoho.com            USA           CA  California
#
#        city_o                    address_o postal_code_p     status  \
# 0    New York  902 Broadway 11th Floor New         10010   acquired
# 1  Pleasanton                    not known     not known  operating
#
#                                  short_description_o  \
# 0  Wetpaint offers an online social publishing pl...
# 1  Zoho offers a suite of business, collaboration...
#
#                                        category_list  \
# 0    Publishing,Social Media,Social Media Management
# 1  Cloud Computing,Collaboration,Developer Tools,...
#
#                                 category_groups_list           founded_on  \
# 0  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 1  Administrative Services,Apps,Information Techn...  1996-03-17 00:00:00
#
#   closed_on employee_count             email_o         phone_o  \
# 0         0         51-100   info@wetpaint.com    206-859-6300
# 1         0         10000+  sales@zohocorp.com  044 - 67447070
#
#                       facebook_url_o                         linkedin_url_o  \
# 0  https://www.facebook.com/Wetpaint                              not known
# 1       http://www.facebook.com/zoho  https://www.linkedin.com/company/zoho
#
#                     twitter_url_o primary_role    name_o    rank_o  \
# 0  https://twitter.com/wetpainttv      company  Wetpaint  194947.0
# 1         http://twitter.com/zoho      company      Zoho    6999.0
#
#                                        description_o  \
# 0  Wetpaint is a technology platform company that...
# 1  Zoho offers a suite of business, collaboration...
#
#                                  uuid_p        name_p   rank_p  \
# 0                                   NaN           NaN      NaN
# 1  9f99a98a-aa97-b30b-0d36-db67c1d277e0  Raju Vegesna  11465.0
#
#             created_at           updated_at first_name last_name gender  \
# 0                  NaN                  NaN        NaN       NaN    NaN
# 1  2007-05-26 02:33:03  2022-02-24 12:24:29       Raju   Vegesna   male
#
#   country_code_p state_code_p    region_p         city_p  \
# 0            NaN          NaN         NaN            NaN
# 1            USA           CA  California  San Francisco
#
#          featured_job_organization_uuid featured_job_organization_name  \
# 0                                   NaN                            NaN
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
#
#   featured_job_title facebook_url_p  \
# 0                NaN            NaN
# 1   Chief Evangelist      not known
#
#                                      linkedin_url_p              twitter_url_p
# 0                                               NaN                        NaN
# 1  https://www.linkedin.com/in/raju-vegesna-78a6541  https://twitter.com/rajuv

# %%
# Add the people description to the backbone dataset
backbone_ds = pd.merge(backbone_ds, people_descriptions, right_on='uuid',left_on='uuid_p', how = 'left')

# %%
backbone_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3133885 entries, 0 to 3133884
# Data columns (total 52 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   uuid_o                          object
#  1   name_o                          object
#  2   type                            object
#  3   rank_o                          float64
#  4   legal_name                      object
#  5   roles_o                         object
#  6   domain                          object
#  7   homepage_url                    object
#  8   country_code_o                  object
#  9   state_code_o                    object
#  10  region_o                        object
#  11  city_o                          object
#  12  address_o                       object
#  13  postal_code_p                   object
#  14  status                          object
#  15  short_description_o             object
#  16  category_list                   object
#  17  category_groups_list            object
#  18  founded_on                      object
#  19  closed_on                       object
#  20  employee_count                  object
#  21  email_o                         object
#  22  phone_o                         object
#  23  facebook_url_o                  object
#  24  linkedin_url_o                  object
#  25  twitter_url_o                   object
#  26  primary_role                    object
#  27  name_o                          object
#  28  rank_o                          float64
#  29  description_o                   object
#  30  uuid_p                          object
#  31  name_p                          object
#  32  rank_p                          float64
#  33  created_at                      object
#  34  updated_at                      object
#  35  first_name                      object
#  36  last_name                       object
#  37  gender                          object
#  38  country_code_p                  object
#  39  state_code_p                    object
#  40  region_p                        object
#  41  city_p                          object
#  42  featured_job_organization_uuid  object
#  43  featured_job_organization_name  object
#  44  featured_job_title              object
#  45  facebook_url_p                  object
#  46  linkedin_url_p                  object
#  47  twitter_url_p                   object
#  48  uuid                            object
#  49  name                            object
#  50  rank                            float64
#  51  description                     object
# dtypes: float64(4), object(48)
# memory usage: 1.2+ GB

# %%
# Remove the unneeded and duplicated columns and rename the description column to description_p
backbone_ds.drop(['uuid','name','rank'],axis=1,inplace=True)
backbone_ds.rename(columns={'description':'description_p'},inplace=True)

# %%
# import the clean version of datasets that would provide features for the backbone dataset (degrees)
degrees = pd.read_csv('data//clean//degrees_c.csv')
degrees.head(2)
# Out:
#                                    uuid    type  \
# 0  205fdfd1-ecac-aa43-262f-219f11755f67  degree
# 1  1a2ac288-eb99-3318-fde5-1517bc168f51  degree
#
#                             person_uuid person_name  \
# 0  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
# 1  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
#
#                        institution_uuid                    institution_name  \
# 0  1eab62d2-15d9-0db7-930f-2aa77d4688e1                   Boston University
# 1  6ae9957a-8fb4-0ab1-73fa-dd547c4d3da4  Washington University in St. Louis
#
#   degree_type             subject           started_on         completed_on  \
# 0          MS  Mass Communication  1988-01-01 00:00:00  1992-01-01 00:00:00
# 1          BA     English, French  1986-01-01 00:00:00  1990-01-01 00:00:00
#
#    is_completed
# 0          True
# 1          True

# %%
# Merge with the degrees table to add the education of the key personnel of the organisation
backbone_ds = pd.merge(backbone_ds, degrees, right_on = 'person_uuid',left_on = 'uuid_p' , how = 'left')

# %%
# Remove the unneeded and duplicated columns and rename the columns
backbone_ds.drop(['uuid','created_at','updated_at','type_y','person_uuid','person_name'],axis=1,inplace=True)
backbone_ds.rename(columns={'type_x':'type_o'},inplace=True)

# %% [markdown]
# We will add the events and fund raising information to this table.
#
# Firstly we will merge the event and event_appearances datasets and format with needed columns only. The information used for the model will be the number of events attended and the role played in the event by the organisation.
#
# Secondly we would merge the acquisitions, investments, funds, funding_rounds and ipos dataset before merging with the backbone dataset.
#
# Lastly, we will merge with the org_parents dataset to bring in the parent company information.

# %%
# import the clean version of datasets that would provide features for the backbone dataset (events)
events = pd.read_csv('data//clean//events_c.csv')
events.head(2)
# Out:
#                                    uuid            name     rank  \
# 0  6a21f93a-3cae-02ac-44c7-c166c0ed50fa     SF New Tech  14384.0
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014  20785.0
#
#                                    short_description  started_on    ended_on  \
# 0  Join us on Wed, Oct 15th for another edition o...  2014-10-14  2014-10-14
# 1  Sessions, labs, and creativity workshops where...  2014-10-04  2014-10-08
#
#    event_url                       registration_url  \
# 0  not known  http://1015sfnt-meetup.eventbrite.com
# 1  not known     http://max.adobe.com/registration/
#
#                       venue_name description country_code state_code  \
# 0                  RocketStudios   not known          USA         CA
# 1  Los Angeles Convention Center   not known          USA         CA
#
#        region           city event_roles
# 0  California  San Francisco  conference
# 1  California    Los Angeles  conference

# %%
# import the clean version of datasets that would provide features for the backbone dataset (events appearances)
event_appearances = pd.read_csv('data//clean//event_appearances_c.csv')
event_appearances.head(2)
# Out:
#                                    uuid  \
# 0  d06f7aaa-7967-426d-9285-74f67ed848b6
# 1  d11986fa-b2c6-4b26-a9fe-dd57312fd9cf
#
#                                     name  \
# 0  AWS re:Invent's sponsor - Trend Micro
# 1        AWS re:Invent's sponsor - Intel
#
#                              event_uuid     event_name  \
# 0  de7f0834-df34-2691-deb3-2fb3f97de046  AWS re:Invent
# 1  de7f0834-df34-2691-deb3-2fb3f97de046  AWS re:Invent
#
#                        participant_uuid participant_name participant_type  \
# 0  cd49293a-a193-4a66-854c-a56ee45beeb5      Trend Micro     organization
# 1  1e4f199c-363b-451b-a164-f94571075ee5            Intel     organization
#
#   appearance_type short_description
# 0         sponsor           diamond
# 1         sponsor           diamond

# %%
# merge the events and event_appearances datasetsabs
event_ds = pd.merge(event_appearances,events, right_on= 'uuid', left_on = 'event_uuid', how = 'left')

# %%
event_ds.head(2)
# Out:
#                                  uuid_x  \
# 0  d06f7aaa-7967-426d-9285-74f67ed848b6
# 1  d11986fa-b2c6-4b26-a9fe-dd57312fd9cf
#
#                                   name_x  \
# 0  AWS re:Invent's sponsor - Trend Micro
# 1        AWS re:Invent's sponsor - Intel
#
#                              event_uuid     event_name  \
# 0  de7f0834-df34-2691-deb3-2fb3f97de046  AWS re:Invent
# 1  de7f0834-df34-2691-deb3-2fb3f97de046  AWS re:Invent
#
#                        participant_uuid participant_name participant_type  \
# 0  cd49293a-a193-4a66-854c-a56ee45beeb5      Trend Micro     organization
# 1  1e4f199c-363b-451b-a164-f94571075ee5            Intel     organization
#
#   appearance_type short_description_x                                uuid_y  \
# 0         sponsor             diamond  de7f0834-df34-2691-deb3-2fb3f97de046
# 1         sponsor             diamond  de7f0834-df34-2691-deb3-2fb3f97de046
#
#           name_y     rank                                short_description_y  \
# 0  AWS re:Invent  19663.0  AWS re: Invent is the largest gathering of the...
# 1  AWS re:Invent  19663.0  AWS re: Invent is the largest gathering of the...
#
#    started_on    ended_on  event_url  \
# 0  2014-11-11  2014-11-14  not known
# 1  2014-11-11  2014-11-14  not known
#
#                                     registration_url  \
# 0  https://www.portal.reinvent.awsevents.com/port...
# 1  https://www.portal.reinvent.awsevents.com/port...
#
#                     venue_name  \
# 0  Venetian and Palazzo Hotels
# 1  Venetian and Palazzo Hotels
#
#                                          description country_code state_code  \
# 0  AWS re:Invent is a learning conference that of...          USA         NV
# 1  AWS re:Invent is a learning conference that of...          USA         NV
#
#    region       city event_roles
# 0  Nevada  Las Vegas  conference
# 1  Nevada  Las Vegas  conference

# %%
# Find the number of events participated in
event_df_ds=pd.DataFrame(event_ds.groupby(['participant_uuid'])['uuid_x'].count())

# %%
# Name the column for number of events participated
event_df_ds.rename(columns={'uuid_x':'num_events_part'},inplace=True)

# %%
# merge the events dataset to the backbone dataset for organizations 
backbone_ds = pd.merge(backbone_ds,event_df_ds,right_on='participant_uuid',left_on='uuid_o', how='left')

# %%
# View the current status of the backbone dataset
backbone_ds.head(2)
# Out:
#                                  uuid_o    name_o        type_o    rank_o  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization    6999.0
#
#                    legal_name           roles_o        domain  \
# 0                   not known           company  wetpaint.com
# 1  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
#
#                homepage_url country_code_o state_code_o    region_o  \
# 0  http://www.wetpaint.com/            USA           NY    New York
# 1      https://www.zoho.com            USA           CA  California
#
#        city_o                    address_o postal_code_p     status  \
# 0    New York  902 Broadway 11th Floor New         10010   acquired
# 1  Pleasanton                    not known     not known  operating
#
#                                  short_description_o  \
# 0  Wetpaint offers an online social publishing pl...
# 1  Zoho offers a suite of business, collaboration...
#
#                                        category_list  \
# 0    Publishing,Social Media,Social Media Management
# 1  Cloud Computing,Collaboration,Developer Tools,...
#
#                                 category_groups_list           founded_on  \
# 0  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 1  Administrative Services,Apps,Information Techn...  1996-03-17 00:00:00
#
#   closed_on employee_count             email_o         phone_o  \
# 0         0         51-100   info@wetpaint.com    206-859-6300
# 1         0         10000+  sales@zohocorp.com  044 - 67447070
#
#                       facebook_url_o  ...        name_p   rank_p first_name  \
# 0  https://www.facebook.com/Wetpaint  ...           NaN      NaN        NaN
# 1       http://www.facebook.com/zoho  ...  Raju Vegesna  11465.0       Raju
#
#   last_name  gender country_code_p state_code_p    region_p         city_p  \
# 0       NaN     NaN            NaN          NaN         NaN            NaN
# 1   Vegesna    male            USA           CA  California  San Francisco
#
#          featured_job_organization_uuid featured_job_organization_name  \
# 0                                   NaN                            NaN
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
#
#   featured_job_title facebook_url_p  \
# 0                NaN            NaN
# 1   Chief Evangelist      not known
#
#                                      linkedin_url_p  \
# 0                                               NaN
# 1  https://www.linkedin.com/in/raju-vegesna-78a6541
#
#                twitter_url_p  \
# 0                        NaN
# 1  https://twitter.com/rajuv
#
#                                        description_p institution_uuid  \
# 0                                                NaN              NaN
# 1  Raju is an evangelist for Zoho and is one of t...              NaN
#
#   institution_name degree_type subject started_on completed_on is_completed  \
# 0              NaN         NaN     NaN        NaN          NaN          NaN
# 1              NaN         NaN     NaN        NaN          NaN          NaN
#
#   num_events_part
# 0             NaN
# 1            12.0
#
# [2 rows x 55 columns]

# %%
# import the clean version of datasets that would provide features for the backbone dataset (acquisitions)
acquisitions = pd.read_csv('data//clean//acquisitions_c.csv')
acquisitions.head(2)
# Out:
#                                    uuid  \
# 0  c62807f2-3487-f63b-e7fc-559b752ed44c
# 1  419cabe1-4d71-5f64-3e9b-c9d0fb445cca
#
#                                         name         type  \
# 0  Flektor acquired by Fox Interactive Media  acquisition
# 1            GrandCentral acquired by Google  acquisition
#
#                           acquiree_uuid acquiree_name acquiree_country_code  \
# 0  180ebf67-68d0-2316-e93d-8e1e546330ba       Flektor                   USA
# 1  5b05e013-a448-3a0b-d872-a6ae668e1192  GrandCentral                   USA
#
#   acquiree_state_code acquiree_region acquiree_city  \
# 0                  CA      California   Culver City
# 1                  CA      California       Fremont
#
#                           acquirer_uuid          acquirer_name  \
# 0  d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media
# 1  6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
#
#   acquirer_country_code acquirer_state_code acquirer_region  acquirer_city  \
# 0                   USA                  CA      California  Beverly Hills
# 1                   USA                  CA      California  Mountain View
#
#   acquisition_type acquired_on   price_usd       price price_currency_code
# 0        not known  2007-05-30         0.0         0.0                 USD
# 1        not known  2007-07-01  60000000.0  60000000.0                 USD

# %%
# Check the columns to drop unneeded ones
acquisitions.columns
# Out:
# Index(['uuid', 'name', 'type', 'acquiree_uuid', 'acquiree_name',
#        'acquiree_country_code', 'acquiree_state_code', 'acquiree_region',
#        'acquiree_city', 'acquirer_uuid', 'acquirer_name',
#        'acquirer_country_code', 'acquirer_state_code', 'acquirer_region',
#        'acquirer_city', 'acquisition_type', 'acquired_on', 'price_usd',
#        'price', 'price_currency_code'],
#       dtype='object')

# %%
# Remove the unneeded columns and rename the acquiree_uuid
acquisitions.drop(['uuid', 'name', 'type', 'acquiree_name',
       'acquiree_country_code', 'acquiree_state_code', 'acquiree_region',
       'acquiree_city','acquirer_country_code', 'acquirer_state_code', 'acquirer_region',
       'acquirer_city', 'acquisition_type','price', 'price_currency_code'],axis=1,inplace=True)

acquisitions.rename(columns={'acquiree_uuid':'org_uuid'},inplace=True)

# %%
# import the clean version of datasets that would provide features for the backbone dataset (funding_rounds)
funding_rounds = pd.read_csv('data//clean//funding_rounds_c.csv')
funding_rounds.head(2)
# Out:
#                                    uuid                name      rank  \
# 0  8a945939-18e0-cc9d-27b9-bf33817b2818  Angel Round - Meta  122966.0
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb     Series A - Meta  508333.0
#
#   country_code state_code      region        city investment_type  \
# 0          USA         CA  California  Menlo Park           angel
# 1          USA         CA  California  Menlo Park        series_a
#
#   announced_on  raised_amount_usd  raised_amount raised_amount_currency_code  \
# 0   2004-09-01           500000.0       500000.0                         USD
# 1   2005-05-01         12700000.0     12700000.0                         USD
#
#                                org_uuid org_name  \
# 0  df662812-7f97-0b43-9d3e-12f64f504fbb     Meta
# 1  df662812-7f97-0b43-9d3e-12f64f504fbb     Meta
#
#                     lead_investor_uuids
# 0  3f47be49-2e32-8118-01a0-31685a4d0fd7
# 1  b08efc27-da40-505a-6f9d-c9e14247bf36

# %%
# Check the columns to drop unneeded ones
funding_rounds.columns
# Out:
# Index(['uuid', 'name', 'rank', 'country_code', 'state_code', 'region', 'city',
#        'investment_type', 'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code', 'org_uuid', 'org_name',
#        'lead_investor_uuids'],
#       dtype='object')

# %%
# Remove the unneeded columns
funding_rounds.drop(['uuid', 'name', 'rank', 'country_code', 'state_code', 'region', 'city',
        'raised_amount','raised_amount_currency_code', 'org_name',
       'lead_investor_uuids'],axis=1,inplace=True)

# %%
# import the clean version of datasets that would provide features for the backbone dataset (investments)
investments = pd.read_csv('data//clean//investments_c.csv')
investments.head(2)
# Out:
#                                    uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d
# 1  6556ab92-6465-25aa-1ffc-7f8b4b09a476
#
#                                      name  \
# 0     Accel investment in Series A - Meta
# 1  Greylock investment in Series B - Meta
#
#                      funding_round_uuid funding_round_name  \
# 0  d950d7a5-79ff-fb93-ca87-13386b0e2feb    Series A - Meta
# 1  6fae3958-a001-27c0-fb7e-666266aedd78    Series B - Meta
#
#                           investor_uuid investor_name investor_type  \
# 0  b08efc27-da40-505a-6f9d-c9e14247bf36         Accel  organization
# 1  e2006571-6b7a-e477-002a-f7014f48a7e3      Greylock  organization
#
#   is_lead_investor
# 0             True
# 1             True

# %%
# import the clean version of datasets that would provide features for the backbone dataset (ipos)
ipos = pd.read_csv('data//clean//ipos_c.csv')
ipos.head(2)
# Out:
#                                    uuid                              org_uuid  \
# 0  72d30ebd-53ef-2486-6c29-22785c5173ce  fd80725f-53fc-7009-9878-aeecf1e9ffbb
# 1  3ad2b068-2d97-f646-0b80-1e5f3d7adfc4  756936c0-c335-f0ae-0a3d-fe26bdff5695
#
#                   org_name country_code state_code      region     city  \
# 0                Microsoft          USA         WA  Washington  Redmond
# 1  The Walt Disney Company          USA         CA  California  Burbank
#
#   stock_exchange_symbol stock_symbol went_public_on  share_price_usd  \
# 0                nasdaq         MSFT     1986-03-13              0.0
# 1                  nyse          DIS     1978-01-13              0.0
#
#    share_price share_price_currency_code  valuation_price_usd  \
# 0          0.0                       USD                  0.0
# 1          0.0                       USD                  0.0
#
#    valuation_price valuation_price_currency_code  money_raised_usd  \
# 0              0.0                           USD               0.0
# 1              0.0                           USD       300000000.0
#
#    money_raised money_raised_currency_code
# 0           0.0                        USD
# 1   300000000.0                        USD

# %%
# Check the columns to drop unneeded ones
ipos.columns
# Out:
# Index(['uuid', 'org_uuid', 'org_name', 'country_code', 'state_code', 'region',
#        'city', 'stock_exchange_symbol', 'stock_symbol', 'went_public_on',
#        'share_price_usd', 'share_price', 'share_price_currency_code',
#        'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code'],
#       dtype='object')

# %%
# Remove the unneeded columns
ipos.drop(['uuid', 'org_name', 'country_code', 'state_code', 'region',
       'city', 'stock_exchange_symbol', 'stock_symbol', 'share_price_usd', 'share_price', 'share_price_currency_code',
       'valuation_price','valuation_price_currency_code', 'money_raised', 'money_raised_currency_code'],
          axis=1,inplace=True)

# %%
# Merge the fund raising and acquisition datasets 
funding_ds = pd.merge(acquisitions,funding_rounds,on='org_uuid',how='outer')
funding_ds
# Out:
#                                     org_uuid  \
# 0       180ebf67-68d0-2316-e93d-8e1e546330ba
# 1       5b05e013-a448-3a0b-d872-a6ae668e1192
# 2       8249dffa-1ca6-6f99-9f76-d56c83f85f2d
# 3       10dd03fa-69ff-3a82-6321-c6b16c9a9f41
# 4       10dd03fa-69ff-3a82-6321-c6b16c9a9f41
# ...                                      ...
# 655073  fab2ec9b-9ee7-476e-9ff5-bf1eeb1cec1c
# 655074  9cd4864e-4a16-4461-ac87-6651dcc384fd
# 655075  c6da9a79-0c30-4318-ab3d-660153f3e94c
# 655076  a88d51ac-9f10-4c88-8aae-222ed9ef6b59
# 655077  eb505a4d-c8f9-41d5-9317-5732df96fafa
#
#                                acquirer_uuid          acquirer_name  \
# 0       d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media
# 1       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 2       f09c1228-2e7d-1889-6647-ba5021b2e4ea      CBS Entertainment
# 3       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 4       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# ...                                      ...                    ...
# 655073                                   NaN                    NaN
# 655074                                   NaN                    NaN
# 655075                                   NaN                    NaN
# 655076                                   NaN                    NaN
# 655077                                   NaN                    NaN
#
#        acquired_on    price_usd        investment_type announced_on  \
# 0       2007-05-30          0.0                    NaN          NaN
# 1       2007-07-01   60000000.0               series_a   2006-04-01
# 2       2007-05-01  280000000.0               series_a   2006-05-01
# 3       2007-05-23  100000000.0               series_a   2004-06-01
# 4       2007-05-23  100000000.0               series_b   2005-04-06
# ...            ...          ...                    ...          ...
# 655073         NaN          NaN                   seed   2023-01-01
# 655074         NaN          NaN  non_equity_assistance   2020-01-01
# 655075         NaN          NaN  non_equity_assistance   2019-01-01
# 655076         NaN          NaN                   seed   2021-10-01
# 655077         NaN          NaN  non_equity_assistance   2019-01-01
#
#         raised_amount_usd
# 0                     NaN
# 1               4000000.0
# 2               5000000.0
# 3               1000000.0
# 4               7000000.0
# ...                   ...
# 655073          3000000.0
# 655074                0.0
# 655075                0.0
# 655076          4000000.0
# 655077                0.0
#
# [655078 rows x 8 columns]

# %%
# Merge the new fund raising dataset and ipos dataset
funding_ds = pd.merge(funding_ds,ipos,on='org_uuid',how='outer')
funding_ds
# Out:
#                                     org_uuid  \
# 0       180ebf67-68d0-2316-e93d-8e1e546330ba
# 1       5b05e013-a448-3a0b-d872-a6ae668e1192
# 2       8249dffa-1ca6-6f99-9f76-d56c83f85f2d
# 3       10dd03fa-69ff-3a82-6321-c6b16c9a9f41
# 4       10dd03fa-69ff-3a82-6321-c6b16c9a9f41
# ...                                      ...
# 692654  4f00ed69-684a-4d99-a977-25eaca764830
# 692655  0983b301-0947-4552-a179-ca4a404d8d8c
# 692656  93c3de7e-e7c3-447e-8a22-83581fb3d91a
# 692657  8f40c79b-5e06-4b4a-9281-352860dfaded
# 692658  6826b1e6-1be9-411e-afc6-b9187030e479
#
#                                acquirer_uuid          acquirer_name  \
# 0       d70777cc-14bd-2416-0692-5a483781b78b  Fox Interactive Media
# 1       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 2       f09c1228-2e7d-1889-6647-ba5021b2e4ea      CBS Entertainment
# 3       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# 4       6acfa7da-1dbd-936e-d985-cf07a1b27711                 Google
# ...                                      ...                    ...
# 692654                                   NaN                    NaN
# 692655                                   NaN                    NaN
# 692656                                   NaN                    NaN
# 692657                                   NaN                    NaN
# 692658                                   NaN                    NaN
#
#        acquired_on    price_usd investment_type announced_on  \
# 0       2007-05-30          0.0             NaN          NaN
# 1       2007-07-01   60000000.0        series_a   2006-04-01
# 2       2007-05-01  280000000.0        series_a   2006-05-01
# 3       2007-05-23  100000000.0        series_a   2004-06-01
# 4       2007-05-23  100000000.0        series_b   2005-04-06
# ...            ...          ...             ...          ...
# 692654         NaN          NaN             NaN          NaN
# 692655         NaN          NaN             NaN          NaN
# 692656         NaN          NaN             NaN          NaN
# 692657         NaN          NaN             NaN          NaN
# 692658         NaN          NaN             NaN          NaN
#
#         raised_amount_usd went_public_on  valuation_price_usd  \
# 0                     NaN            NaN                  NaN
# 1               4000000.0            NaN                  NaN
# 2               5000000.0            NaN                  NaN
# 3               1000000.0            NaN                  NaN
# 4               7000000.0            NaN                  NaN
# ...                   ...            ...                  ...
# 692654                NaN     2023-02-10         0.000000e+00
# 692655                NaN     2023-02-09         1.108278e+07
# 692656                NaN     2023-02-09         1.049700e+10
# 692657                NaN     2023-02-09         0.000000e+00
# 692658                NaN     2023-02-10         0.000000e+00
#
#         money_raised_usd
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 692654               0.0
# 692655        91374000.0
# 692656       663198385.0
# 692657               0.0
# 692658        60000000.0
#
# [692659 rows x 11 columns]

# %%
# The funding_ds will now be merged with the backbone_ds
backbone_ds = pd.merge(backbone_ds,funding_ds,right_on='org_uuid',left_on='uuid_o',how='left')

# %%
backbone_ds.head()
# Out:
#                                  uuid_o    name_o        type_o    rank_o  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 1  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 2  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  194947.0
# 3  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization    6999.0
# 4  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization    6999.0
#
#                    legal_name           roles_o        domain  \
# 0                   not known           company  wetpaint.com
# 1                   not known           company  wetpaint.com
# 2                   not known           company  wetpaint.com
# 3  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
# 4  Zoho Corporation Pvt. Ltd.  investor,company      zoho.com
#
#                homepage_url country_code_o state_code_o    region_o  \
# 0  http://www.wetpaint.com/            USA           NY    New York
# 1  http://www.wetpaint.com/            USA           NY    New York
# 2  http://www.wetpaint.com/            USA           NY    New York
# 3      https://www.zoho.com            USA           CA  California
# 4      https://www.zoho.com            USA           CA  California
#
#        city_o                    address_o postal_code_p     status  \
# 0    New York  902 Broadway 11th Floor New         10010   acquired
# 1    New York  902 Broadway 11th Floor New         10010   acquired
# 2    New York  902 Broadway 11th Floor New         10010   acquired
# 3  Pleasanton                    not known     not known  operating
# 4  Pleasanton                    not known     not known  operating
#
#                                  short_description_o  \
# 0  Wetpaint offers an online social publishing pl...
# 1  Wetpaint offers an online social publishing pl...
# 2  Wetpaint offers an online social publishing pl...
# 3  Zoho offers a suite of business, collaboration...
# 4  Zoho offers a suite of business, collaboration...
#
#                                        category_list  \
# 0    Publishing,Social Media,Social Media Management
# 1    Publishing,Social Media,Social Media Management
# 2    Publishing,Social Media,Social Media Management
# 3  Cloud Computing,Collaboration,Developer Tools,...
# 4  Cloud Computing,Collaboration,Developer Tools,...
#
#                                 category_groups_list           founded_on  \
# 0  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 1  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 2  Content and Publishing,Internet Services,Media...  2005-06-01 00:00:00
# 3  Administrative Services,Apps,Information Techn...  1996-03-17 00:00:00
# 4  Administrative Services,Apps,Information Techn...  1996-03-17 00:00:00
#
#   closed_on employee_count             email_o         phone_o  \
# 0         0         51-100   info@wetpaint.com    206-859-6300
# 1         0         51-100   info@wetpaint.com    206-859-6300
# 2         0         51-100   info@wetpaint.com    206-859-6300
# 3         0         10000+  sales@zohocorp.com  044 - 67447070
# 4         0         10000+  sales@zohocorp.com  044 - 67447070
#
#                       facebook_url_o  ...       featured_job_title  \
# 0  https://www.facebook.com/Wetpaint  ...                      NaN
# 1  https://www.facebook.com/Wetpaint  ...                      NaN
# 2  https://www.facebook.com/Wetpaint  ...                      NaN
# 3       http://www.facebook.com/zoho  ...         Chief Evangelist
# 4       http://www.facebook.com/zoho  ...  VP Business Development
#
#   facebook_url_p                                    linkedin_url_p  \
# 0            NaN                                               NaN
# 1            NaN                                               NaN
# 2            NaN                                               NaN
# 3      not known  https://www.linkedin.com/in/raju-vegesna-78a6541
# 4      not known                                         not known
#
#                twitter_url_p  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  https://twitter.com/rajuv
# 4                  not known
#
#                                        description_p  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Raju is an evangelist for Zoho and is one of t...
# 4  Ian Wenig has more then twenty years experienc...
#
#                        institution_uuid   institution_name degree_type  \
# 0                                   NaN                NaN         NaN
# 1                                   NaN                NaN         NaN
# 2                                   NaN                NaN         NaN
# 3                                   NaN                NaN         NaN
# 4  d3f1f735-51c9-3306-04c0-0aa115b5ce43  McGill University          BS
#
#                subject           started_on         completed_on is_completed  \
# 0                  NaN                  NaN                  NaN          NaN
# 1                  NaN                  NaN                  NaN          NaN
# 2                  NaN                  NaN                  NaN          NaN
# 3                  NaN                  NaN                  NaN          NaN
# 4  Biology, Psychology  1982-01-01 00:00:00  1986-01-01 00:00:00         True
#
#   num_events_part                              org_uuid  \
# 0             NaN  e1393508-30ea-8a36-3f96-dd3226033abd
# 1             NaN  e1393508-30ea-8a36-3f96-dd3226033abd
# 2             NaN  e1393508-30ea-8a36-3f96-dd3226033abd
# 3            12.0                                   NaN
# 4            12.0                                   NaN
#
#                           acquirer_uuid acquirer_name acquired_on   price_usd  \
# 0  4be40c73-8cd5-fdb5-b1d5-3597a0d92afa  Viggle, Inc.  2013-12-16  30000000.0
# 1  4be40c73-8cd5-fdb5-b1d5-3597a0d92afa  Viggle, Inc.  2013-12-16  30000000.0
# 2  4be40c73-8cd5-fdb5-b1d5-3597a0d92afa  Viggle, Inc.  2013-12-16  30000000.0
# 3                                   NaN           NaN         NaN         NaN
# 4                                   NaN           NaN         NaN         NaN
#
#   investment_type announced_on raised_amount_usd went_public_on  \
# 0        series_a   2005-10-01         5250000.0            NaN
# 1        series_b   2007-01-01         9500000.0            NaN
# 2        series_c   2008-05-19        25000000.0            NaN
# 3             NaN          NaN               NaN            NaN
# 4             NaN          NaN               NaN            NaN
#
#   valuation_price_usd money_raised_usd
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
#
# [5 rows x 66 columns]

# %%
# Save the backbone_ds as a first step before merging with the scraped dataset, cleaning and preparing the final dataset for model training
backbone_ds.to_csv('data/backbone.csv',index=False)
